# %% [markdown]
# # PROJET KAYAK

# %% [markdown]
# ## Etape 0 : Paramétrage général du projet

# %% [markdown]
# ### Import des librairies

# %%
#Import des librairies nécessaires
import numpy as np
#Import de la librairie request effectuer les requêtes HTTP
import requests
#import de la librairie Pandas
import pandas as pd
#Librairie de gestion des dates
import datetime
#Pour les graphes
import plotly.graph_objects as go
#Librairie pour le scrapping
import os 
import logging
from scrapy.crawler import CrawlerProcess

#Librairie pour Amazon services
import boto3

# Librairie sql alchemy
from sqlalchemy import create_engine, text, inspect

#Time nous permet de faire des sleep
import time

#Option pour afficher la totalité des colonnes d'un DF
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Liste des villes à gérer

# %%
#Définition de la liste des villes (35)
liste_ville = ["Mont Saint Michel",
"St Malo",
"Bayeux",
"Le Havre",
"Rouen",
"Paris",
"Amiens",
"Lille",
"Strasbourg",
"Chateau du Haut Koenigsbourg",
"Colmar",
"Eguisheim",
"Besancon",
"Dijon",
"Annecy",
"Grenoble",
"Lyon",
"Gorges du Verdon",
"Bormes les Mimosas",
"Cassis",
"Marseille",
"Aix en Provence",
"Avignon",
"Uzes",
"Nimes",
"Aigues Mortes",
"Saintes Maries de la mer",
"Collioure",
"Carcassonne",
"Ariege",
"Toulouse",
"Montauban",
"Biarritz",
"Bayonne",
"La Rochelle"]

# %% [markdown]
# ### Paramétrage du script

# %%
#Définition des paramètres
#Mode de fonctionnement 
#full : le scraping va chercher toutes les informations sur l'hotel (description et latitude + longitude) (+ long)
#price : le scraping va chercher uniquement les informations du prix
#Attention le mode intervient aussi dans l'écriture des infos en base de données (si full on écrase et on réécrit)
mode = 'full'

#Récupération des datas sans faire appel aux api(via fichier local)
local_mode = False
#Empêche de lancer un scrapping
no_scrap = False

#Upload sur RDS
rds_mode = False

#clés API
#Définition d'une variable de clé d'API OPENWEATHER
API_KEY_OW = os.environ['API_KEY_OW']

#Clé API pour mapbox
mapbox_access_token = os.environ['MAP_BOX_TOKEN']

#Clé amazon : Bonne pratique : à mettre en variable d'environnement
aws_key=os.environ['AWS_ACCESS_KEY_ID']
aws_secret=os.environ['AWS_SECRET_ACCESS_KEY']
bucket_name = 'jedha-kayak-q25sd4qs8d4q2'

#Param pour RDS
p_DBName="kayak_project"
p_DBInstanceIdentifier="kaykainstance"
p_MasterUsername="jedhakayakroot"
p_MasterUserPassword="lkjds4f4sd25*sd4f354s35df4"


#Date du séjour 
#info: comme l'api météo ne donne que sur 7 jours de prévision les dates du voyages doivent être entre J et J+7
date_sejour = '2023-05-06'
duree_sejour = 4

# %%
#Calcul Parametre date de fin du séjour
jour = datetime.date(int(date_sejour[0:4]),int(date_sejour[5:7]),int(date_sejour[8:10]))
duree = datetime.timedelta(days = duree_sejour)
date_fin_sejour = jour + duree
date_fin_sejour = date_fin_sejour.isoformat()
print('La date de fin de séjour est : '+date_fin_sejour)
# Out:
# La date de fin de séjour est : 2023-05-10

# %%
#Affichage des infos 
print('Résumé des paramètres')
print('Nombre de villes : '+str(len(liste_ville)))
print('Date arrivée : '+date_sejour)
print('Date départ : '+date_fin_sejour)
print('Nombres de jours : ' + str(duree_sejour))
# Out:
# Résumé des paramètres
# Nombre de villes : 35
# Date arrivée : 2023-05-06
# Date départ : 2023-05-10
# Nombres de jours : 4

# %% [markdown]
# ## Etape 1 : Récupération des informations de l'API nominatim

# %%
#Boucle sur la liste des villes pour récupérer les coordonées latitude et longitude : en sortie un dictionnaire
#Appel à l'API nominatim afin de récupérer la latitude et la longitude
#Paramètres : 
#countrycodes=FR : On filtre ici directement sur la FRANCE(FR) car toutes les villes du scope sont françaises
#limit=1 : Limitation des résultats à 1, en effet, tous les résultats approchants ou moins "intéressants" n'ont pas d'interet ici
#format=json : format de retour demandé à l'API, le json c'est le plus classique
#city= XXXX : on indique ici la ville à récupérer
#TODO possible : Faire des appels asynchrones pour gagner du temps

if not local_mode:
    #initialisation du dictionnaire final qui comprendra une ville, lattitude et longitude
    dict_ville = dict()

    #Boucle sur les villes
    for ville in liste_ville:
        try:
        
            #Requete HTTP, on remplace les eventuels espaces par %20
            response = requests.get("https://nominatim.openstreetmap.org/search?countrycodes=FR&limit=1&format=json&city="+ville.replace(' ','%20'))
            
            #L'API renvoie du vide si rien n'est trouvé mais avec un code 200 (OK)
            if len(response.json()) == 0:
            
                #Si la reponse est vide pour la ville, recherche avec paramètre q= qui permet d'effectuer une recherche large, pas forcement sur une ville
                response = requests.get("https://nominatim.openstreetmap.org/search?countrycodes=FR&limit=1&format=json&q="+ville.replace(' ','%20'))
            
            #Ajout des informations récupérées dans le dictionnaire
            dict_ville.update({ville:{'lat':response.json()[0]['lat'] ,'lon':response.json()[0]['lon']}})
        
        #gestion d'erreur minimaliste
        except:
            print('un problème a eu lieu sur la récupération des informations de la ville',ville)

        
    print(dict_ville)
# Out:
# {'Mont Saint Michel': {'lat': '48.6359541', 'lon': '-1.511459954959514'}, 'St Malo': {'lat': '48.649518', 'lon': '-2.0260409'}, 'Bayeux': {'lat': '49.2764624', 'lon': '-0.7024738'}, 'Le Havre': {'lat': '49.4938975', 'lon': '0.1079732'}, 'Rouen': {'lat': '49.4404591', 'lon': '1.0939658'}, 'Paris': {'lat': '48.8534951', 'lon': '2.3483915'}, 'Amiens': {'lat': '49.8941708', 'lon': '2.2956951'}, 'Lille': {'lat': '50.6365654', 'lon': '3.0635282'}, 'Strasbourg': {'lat': '48.584614', 'lon': '7.7507127'}, 'Chateau du Haut Koenigsbourg': {'lat': '48.2495226', 'lon': '7.3454923'}, 'Colmar': {'lat': '48.0777517', 'lon': '7.3579641'}, 'Eguisheim': {'lat': '48.0447968', 'lon': '7.3079618'}, 'Besancon': {'lat': '47.2380222', 'lon': '6.0243622'}, 'Dijon': {'lat': '47.3215806', 'lon': '5.0414701'}, 'Annecy': {'lat': '45.8992348', 'lon': '6.1288847'}, 'Grenoble': {'lat': '45.1875602', 'lon': '5.7357819'}, 'Lyon': {'lat': '45.7578137', 'lon': '4.8320114'}, 'Gorges du Verdon': {'lat': '43.7496562', 'lon': '6.3285616'}, 'Bormes les Mimosas': {'lat': '43.1506968', 'lon': '6.3419285'}, 'Cassis': {'lat': '43.2140359', 'lon': '5.5396318'}, 'Marseille': {'lat': '43.2961743', 'lon': '5.3699525'}, 'Aix en Provence': {'lat': '43.5298424', 'lon': '5.4474738'}, 'Avignon': {'lat': '43.9492493', 'lon': '4.8059012'}, 'Uzes': {'lat': '44.0121279', 'lon': '4.4196718'}, 'Nimes': {'lat': '43.8374249', 'lon': '4.3600687'}, 'Aigues Mortes': {'lat': '43.5658225', 'lon': '4.1912837'}, 'Saintes Maries de la mer': {'lat': '43.4522771', 'lon': '4.4287172'}, 'Collioure': {'lat': '42.52505', 'lon': '3.0831554'}, 'Carcassonne': {'lat': '43.2130358', 'lon': '2.3491069'}, 'Ariege': {'lat': '42.9455368', 'lon': '1.4065544156065486'}, 'Toulouse': {'lat': '43.6044622', 'lon': '1.4442469'}, 'Montauban': {'lat': '44.0175835', 'lon': '1.3549991'}, 'Biarritz': {'lat': '43.4832523', 'lon': '-1.5592776'}, 'Bayonne': {'lat': '43.4945144', 'lon': '-1.4736657'}, 'La Rochelle': {'lat': '46.1591126', 'lon': '-1.1520434'}}

# %%
#Création d'un DF à partir du dictionnaire = en sortie le Dataframe ville_df
if not local_mode:
    #Le dictionnaire créé nous permet de créer le dataframe final, orient='index' permet d'indiqué que chaque element du dictionnaire est une ligne 
    ville_df = pd.DataFrame.from_dict(dict_ville,orient='index')
    #Par défaut le DF retourné contient la clé en index, retour a un index numérique
    ville_df.reset_index(inplace=True)
    #Clean du nom des colonnes
    ville_df.rename(columns={'index':'Ville','lat':'Latitude','lon':'Longitude'},inplace=True)
    #Affichage
    ville_df.head()

# %% [markdown]
# ## Etape 2 : Récupération des informations de l'API OpenWeather

# %%
#Appel à l'api openweather : En sortie le dataframe df_result avec les données sur tous les jours de l'API + df_avg représentant les valeurs moyennes pour la période du séjour
if not local_mode:
    #Liste de dataframe finale (1 par ville )
    df_list = []
    #Boucle sur le dataframe de l'étape précédente
    for i in ville_df.index:
    #for i in range(0,3):
        #Récupération des variables utiles pour la requêtes météo 
        ville = ville_df.iloc[i,0]
        lat = ville_df.iloc[i,1]
        lon = ville_df.iloc[i,2]

        #appel API paramètres :
        #units=metric : Type d'unité (système métric)
        #lang=fr : Récupération des textes au format français
        #exclude=current,minutely,hourly,alerts : Nous cherchons des données journalières, donc on exclu les données actuelles, à la minute, à l'heure et les alertes
        #appid : Clé API
        response = requests.get("https://api.openweathermap.org/data/3.0/onecall?units=metric&lang=fr&lat="+str(lat)+"&lon="+str(lon)+"&exclude=current,minutely,hourly,alerts&appid="+API_KEY_OW)
        resp_j = response.json()  
        #Conversion d'une partie du JSON au format dataframe (la partie daily contient le forecast des 8 prochains jours)
        #La fonction json_normalize permet la mise à plat du json, utile pour les champs de daily qui contiennent un dictionnaire ou une liste
        df_t = pd.json_normalize(resp_j['daily'])
        # Ajout d'informations au Dataframe 
        df_t.insert(0, 'Timezone_offset',resp_j['timezone_offset'], allow_duplicates=False)
        df_t.insert(0, 'Timezone',resp_j['timezone'], allow_duplicates=False)
        df_t.insert(0, 'Latitude_return',resp_j['lat'], allow_duplicates=False)
        df_t.insert(0, 'Longitude_return',resp_j['lon'], allow_duplicates=False)
        df_t.insert(0, 'Latitude_asked',lat, allow_duplicates=False)
        df_t.insert(0, 'Longitude_asked',lon, allow_duplicates=False)
        df_t.insert(0, 'Ville',ville, allow_duplicates=False)
        df_t.insert(0, 'Ville_Id',i, allow_duplicates=False)
        #Ajout du dataframe Temporaire à la liste 
        df_list.append(df_t)
    
    #Concaténation du résultat en un seul dataframe avec son propre index
    df_result = pd.concat(df_list,ignore_index=True)
    #Transformation des colonnes time Unix en datetime
    df_result.insert(8, 'Sunrise',pd.to_datetime(df_result['sunrise'],unit='s'), allow_duplicates=False)
    df_result.insert(8, 'Sunset',pd.to_datetime(df_result['sunset'],unit='s'), allow_duplicates=False)
    df_result.insert(8, 'Moonrise',pd.to_datetime(df_result['moonrise'],unit='s'), allow_duplicates=False)
    df_result.insert(8, 'Moonset',pd.to_datetime(df_result['moonset'],unit='s'), allow_duplicates=False)
    df_result.insert(8, 'Date',pd.to_datetime(df_result['dt'],unit='s'), allow_duplicates=False)
    df_result.drop(columns=['sunrise', 'sunset','moonrise','moonset','dt'],inplace=True)
    #Désencapsulation de la colonne weather
    df_result.insert(20,'weather.icon',df_result['weather'][0][0]['icon'], allow_duplicates=False)
    df_result.insert(20,'weather.description',df_result['weather'][0][0]['description'], allow_duplicates=False)
    df_result.insert(20,'weather.main',df_result['weather'][0][0]['main'], allow_duplicates=False)
    df_result.insert(20,'weather.id',df_result['weather'][0][0]['id'], allow_duplicates=False)
    df_result.drop(columns=['weather'],inplace=True)


    #TODO possible rajouter le mode des valeurs de temps (la valeur la plus représenter dans la meteo (nuageux ensoleillé etc...))
    #Calcul des aggrégations des différents indicateurs
    df_avg =  df_result.groupby(['Ville_Id','Ville','Latitude_return','Longitude_return']).agg(
                avg_humidity = pd.NamedAgg(column='humidity', aggfunc="mean"),
                avg_wind_speed = pd.NamedAgg(column='wind_speed', aggfunc="mean"),
                avg_clouds = pd.NamedAgg(column='clouds', aggfunc="mean"),
                avg_pop = pd.NamedAgg(column='pop', aggfunc="mean"),
                sum_rain = pd.NamedAgg(column='rain', aggfunc="sum"),
                avg_feel_temp = pd.NamedAgg(column='feels_like.day', aggfunc="mean"),
                ).reset_index()
    
else:
    df_result=pd.read_csv('./testing_data/df_result.csv')
    df_avg=pd.read_csv('./testing_data/df_avg.csv')

# %%
#Sauvegarde au format CSV en local 
#Si on est en local mode, on écrit les données directement dans le dossier de retour de s3 car on ne fera pas appel a s3
if local_mode:
    df_result.to_csv('./data_from_s3/df_result.csv')
    df_avg.to_csv('./data_from_s3/df_avg.csv')
else:
    df_result.to_csv('./data/df_result.csv')
    df_avg.to_csv('./data/df_avg.csv')

# %% [markdown]
# ## Etape 3 : Scrapping des données sur BOOKING.COM

# %%
#Import du spyder
from scrap_booking import BookingSpider 

#Si le paramètre général est à False on lance le scrapping sinon non
if not no_scrap:

    # Name of the file where the results will be saved
    filename = "booking_scrap.json"

    # If file already exists, delete it before crawling (because Scrapy will 
    # concatenate the last and new results otherwise)
    if filename in os.listdir('data/'):
            os.remove('data/' + filename)

    # Declare a new CrawlerProcess with some settings
    ## USER_AGENT => Simulates a browser on an OS
    ## LOG_LEVEL => Minimal Level of Log 
    ## FEEDS => Where the file will be stored 
    ## More info on built-in settings => https://docs.scrapy.org/en/latest/topics/settings.html?highlight=settings#settings
    process = CrawlerProcess(settings = {
        'USER_AGENT': 'Chrome/97.0',
        'LOG_LEVEL': logging.INFO,
        "FEEDS": {
            'data/' + filename : {"format": "json"},
        
        },
        'FEED_EXPORT_ENCODING' : 'utf-8'
    })


    # Start the crawling using the spider you defined above, en mode full on va chercher les informations sur une autre page 
    # ce qui augmente la durée de traitement par hotel
    process.crawl(BookingSpider,list_ville=liste_ville,date_in=date_sejour,date_out=date_fin_sejour,refresh_mode = mode)
    process.start()
# Out:
# 2023-05-04 19:02:34 [scrapy.utils.log] INFO: Scrapy 2.8.0 started (bot: scrapybot)
# 2023-05-04 19:02:34 [scrapy.utils.log] INFO: Versions: lxml 4.9.2.0, libxml2 2.9.14, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.1, Twisted 22.10.0, Python 3.11.3 (main, May  4 2023, 01:51:29) [GCC 10.2.1 20210110], pyOpenSSL 23.1.1 (OpenSSL 3.1.0 14 Mar 2023), cryptography 40.0.2, Platform Linux-5.15.49-linuxkit-aarch64-with-glibc2.31
# 2023-05-04 19:02:34 [scrapy.crawler] INFO: Overridden settings:
# {'DOWNLOAD_DELAY': 2,
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'LOG_LEVEL': 20,
#  'USER_AGENT': 'Chrome/97.0'}
# 2023-05-04 19:02:34 [py.warnings] WARNING: /usr/local/lib/python3.11/site-packages/scrapy/utils/request.py:232: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2023-05-04 19:02:34 [scrapy.extensions.telnet] INFO: Telnet Password: 31744a0e8cec5cb3
# 2023-05-04 19:02:34 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2023-05-04 19:02:34 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-05-04 19:02:34 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-05-04 19:02:34 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-05-04 19:02:34 [scrapy.core.engine] INFO: Spider opened
# 2023-05-04 19:02:35 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-05-04 19:02:35 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2023-05-04 19:02:35 [root] INFO: >>>>URL POUR LA VILLE DE Mont Saint Michel
# 2023-05-04 19:02:35 [root] INFO: https://www.booking.com/searchresults.fr.html?ss=Mont%20Saint%20Michel&checkin=2023-05-06&checkout=2023-05-10&group_adults=2&ac_langcode=fr&order=review_score_and_price
# 2023-05-04 19:02:35 [root] INFO: >>>>URL POUR LA VILLE DE St Malo
# 2023-05-04 19:02:35 [root] INFO: https://www.booking.com/searchresults.fr.html?ss=St%20Malo&checkin=2023-05-06&checkout=2023-05-10&group_adults=2&ac_langcode=fr&order=review_score_and_price
# 2023-05-04 19:02:35 [root] INFO: >>>>URL POUR LA VILLE DE Bayeux
# 2023-05-04 19:02:35 [root] INFO: https://www.booking.com/searchresults.fr.html?ss=Bayeux&checkin=2023-05-06&checkout=2023-05-10&group_adults=2&ac_langcode=fr&order=review_score_and_price
# 2023-05-04 19:02:35 [root] INFO: >>>>URL POUR LA VILLE DE Le Havre
# 2023-05-04 19:02:35 [root] INFO: https://www.booking.com/searchresults.fr.html?ss=Le%20Havre&checkin=2023-05-06&checkout=2023-05-10&group_adults=2&ac_langcode=fr&order=review_score_and_price
# 2023-05-04 19:02:35 [root] INFO: >>>>URL POUR LA VILLE DE Rouen
# 2023-05-04 19:02:35 [root] INFO: https://www.booking.com/searchresults.fr.html?ss=Rouen&checkin=2023-05-06&checkout=2023-05-10&group_adults=2&ac_langcode=fr&order=review_score_and_price
# 2023-05-04 19:02:35 [root] INFO: >>>>URL POUR LA VILLE DE Paris
# 2023-05-04 19:02:35 [root] INFO: https://www.booking.com/searchresults.fr.html?ss=Paris&checkin=2023-05-06&checkout=2023-05-10&group_adults=2&ac_langcode=fr&order=review_score_and_price
# 2023-05-04 19:02:35 [root] INFO: >>>>URL POUR LA VILLE DE Amiens
# 2023-05-04 19:02:35 [root] INFO: https://www.booking.com/searchresults.fr.html?ss=Amiens&checkin=2023-05-06&checkout=2023-05-10&group_adults=2&ac_langcode=fr&order=review_score_and_price
# 2023-05-04 19:02:35 [root] INFO: >>>>URL POUR LA VILLE DE Lille
# 2023-05-04 19:02:35 [root] INFO: https://www.booking.com/searchresults.fr.html?ss=Lille&checkin=2023-05-06&checkout=2023-05-10&group_adults=2&ac_langcode=fr&order=review_score_and_price
# 2023-05-04 19:02:35 [root] INFO: >>>>URL POUR LA VILLE DE Strasbourg
# 2023-05-04 19:02:35 [root] INFO: https://www.booking.com/searchresults.fr.html?ss=Strasbourg&checkin=2023-05-06&checkout=2023-05-10&group_adults=2&ac_langcode=fr&order=review_score_and_price
# 2023-05-04 19:02:35 [root] INFO: >>>>URL POUR LA VILLE DE Chateau du Haut Koenigsbourg
# 2023-05-04 19:02:35 [root] INFO: https://www.booking.com/searchresults.fr.html?ss=Chateau%20du%20Haut%20Koenigsbourg&checkin=2023-05-06&checkout=2023-05-10&group_adults=2&ac_langcode=fr&order=review_score_and_price
# 2023-05-04 19:02:35 [root] INFO: >>>>URL POUR LA VILLE DE Colmar
# 2023-05-04 19:02:35 [root] INFO: https://www.booking.com/searchresults.fr.html?ss=Colmar&checkin=2023-05-06&checkout=2023-05-10&group_adults=2&ac_langcode=fr&order=review_score_and_price
# 2023-05-04 19:02:35 [root] INFO: >>>>URL POUR LA VILLE DE Eguisheim
# 2023-05-04 19:02:35 [root] INFO: https://www.booking.com/searchresults.fr.html?ss=Eguisheim&checkin=2023-05-06&checkout=2023-05-10&group_adults=2&ac_langcode=fr&order=review_score_and_price
# 2023-05-04 19:02:35 [root] INFO: >>>>URL POUR LA VILLE DE Besancon
# 2023-05-04 19:02:35 [root] INFO: https://www.booking.com/searchresults.fr.html?ss=Besancon&checkin=2023-05-06&checkout=2023-05-10&group_adults=2&ac_langcode=fr&order=review_score_and_price
# 2023-05-04 19:02:35 [root] INFO: >>>>URL POUR LA VILLE DE Dijon
# 2023-05-04 19:02:35 [root] INFO: https://www.booking.com/searchresults.fr.html?ss=Dijon&checkin=2023-05-06&checkout=2023-05-10&group_adults=2&ac_langcode=fr&order=review_score_and_price
# 2023-05-04 19:02:35 [root] INFO: >>>>URL POUR LA VILLE DE Annecy
# 2023-05-04 19:02:35 [root] INFO: https://www.booking.com/searchresults.fr.html?ss=Annecy&checkin=2023-05-06&checkout=2023-05-10&group_adults=2&ac_langcode=fr&order=review_score_and_price
# 2023-05-04 19:02:35 [root] INFO: >>>>URL POUR LA VILLE DE Grenoble
# 2023-05-04 19:02:35 [root] INFO: https://www.booking.com/searchresults.fr.html?ss=Grenoble&checkin=2023-05-06&checkout=2023-05-10&group_adults=2&ac_langcode=fr&order=review_score_and_price
# 2023-05-04 19:02:38 [root] INFO: >>>>URL POUR LA VILLE DE Lyon
# 2023-05-04 19:02:38 [root] INFO: https://www.booking.com/searchresults.fr.html?ss=Lyon&checkin=2023-05-06&checkout=2023-05-10&group_adults=2&ac_langcode=fr&order=review_score_and_price
# 2023-05-04 19:02:38 [py.warnings] WARNING: /usr/local/lib/python3.11/site-packages/scrapy/selector/unified.py:83: UserWarning: Selector got both text and root, root is being ignored.
#   super().__init__(text=text, type=st, root=root, **kwargs)
#
# 2023-05-04 19:02:38 [root] INFO: Ville : Mont Saint Michel Le nombre de page à scrapper a été forcé à 1
# 2023-05-04 19:02:40 [py.warnings] WARNING: /usr/local/lib/python3.11/site-packages/scrapy/selector/unified.py:83: UserWarning: Selector got both text and root, root is being ignored.
#   super().__init__(text=text, type=st, root=root, **kwargs)
#
# 2023-05-04 19:02:40 [root] INFO: Ville : St Malo Le nombre de page à scrapper : 3
# 2023-05-04 19:02:41 [py.warnings] WARNING: /usr/local/lib/python3.11/site-packages/scrapy/selector/unified.py:83: UserWarning: Selector got both text and root, root is being ignored.
#   super().__init__(text=text, type=st, root=root, **kwargs)
#
# 2023-05-04 19:02:41 [root] INFO: Ville : Bayeux Le nombre de page à scrapper : 2
# 2023-05-04 19:02:43 [py.warnings] WARNING: /usr/local/lib/python3.11/site-packages/scrapy/selector/unified.py:83: UserWarning: Selector got both text and root, root is being ignored.
#   super().__init__(text=text, type=st, root=root, **kwargs)
#
# 2023-05-04 19:02:44 [root] INFO: Ville : Le Havre Le nombre de page à scrapper : 2
# 2023-05-04 19:02:46 [py.warnings] WARNING: /usr/local/lib/python3.11/site-packages/scrapy/selector/unified.py:83: UserWarning: Selector got both text and root, root is being ignored.
#   super().__init__(text=text, type=st, root=root, **kwargs)
#
# 2023-05-04 19:02:46 [root] INFO: Ville : Rouen Le nombre de page à scrapper : 5
# 2023-05-04 19:02:49 [py.warnings] WARNING: /usr/local/lib/python3.11/site-packages/scrapy/selector/unified.py:83: UserWarning: Selector got both text and root, root is being ignored.
#   super().__init__(text=text, type=st, root=root, **kwargs)
#
# 2023-05-04 19:02:49 [root] INFO: Ville : Paris Le nombre de page à scrapper : 1
# 2023-05-04 19:02:52 [py.warnings] WARNING: /usr/local/lib/python3.11/site-packages/scrapy/selector/unified.py:83: UserWarning: Selector got both text and root, root is being ignored.
#   super().__init__(text=text, type=st, root=root, **kwargs)
#
# 2023-05-04 19:02:52 [root] INFO: Ville : Amiens Le nombre de page à scrapper : 3
# 2023-05-04 19:02:54 [py.warnings] WARNING: /usr/local/lib/python3.11/site-packages/scrapy/selector/unified.py:83: UserWarning: Selector got both text and root, root is being ignored.
#   super().__init__(text=text, type=st, root=root, **kwargs)
#
# 2023-05-04 19:02:54 [root] INFO: Ville : Lille Le nombre de page à scrapper : 3
# 2023-05-04 19:02:56 [py.warnings] WARNING: /usr/local/lib/python3.11/site-packages/scrapy/selector/unified.py:83: UserWarning: Selector got both text and root, root is being ignored.
#   super().__init__(text=text, type=st, root=root, **kwargs)
#
# 2023-05-04 19:02:56 [root] INFO: Ville : Strasbourg Le nombre de page à scrapper : 2
# 2023-05-04 19:02:58 [py.warnings] WARNING: /usr/local/lib/python3.11/site-packages/scrapy/selector/unified.py:83: UserWarning: Selector got both text and root, root is being ignored.
#   super().__init__(text=text, type=st, root=root, **kwargs)
#
# 2023-05-04 19:02:58 [root] INFO: Ville : Chateau du Haut Koenigsbourg Le nombre de page à scrapper : 5
# 2023-05-04 19:03:01 [py.warnings] WARNING: /usr/local/lib/python3.11/site-packages/scrapy/selector/unified.py:83: UserWarning: Selector got both text and root, root is being ignored.
#   super().__init__(text=text, type=st, root=root, **kwargs)
#
# 2023-05-04 19:03
[py.warnings] WARNING: /usr/local/lib/python3.11/site-packages/scrapy/selector/unified.py:83: UserWarning: Selector got both text and root, root is being ignored.
#   super().__init__(text=text, type=st, root=root, **kwargs)
#
# 2023-05-04 19:33:56 [root] INFO: Nombre de property-card pour la ville Rouen : 25
# 2023-05-04 19:33:58 [py.warnings] WARNING: /usr/local/lib/python3.11/site-packages/scrapy/selector/unified.py:83: UserWarning: Selector got both text and root, root is being ignored.
#   super().__init__(text=text, type=st, root=root, **kwargs)
#
# 2023-05-04 19:33:58 [root] INFO: Nombre de property-card pour la ville Rouen : 25
# 2023-05-04 19:34:01 [py.warnings] WARNING: /usr/local/lib/python3.11/site-packages/scrapy/selector/unified.py:83: UserWarning: Selector got both text and root, root is being ignored.
#   super().__init__(text=text, type=st, root=root, **kwargs)
#
# 2023-05-04 19:34:01 [root] INFO: Nombre de property-card pour la ville Rouen : 25
# 2023-05-04 19:34:03 [py.warnings] WARNING: /usr/local/lib/python3.11/site-packages/scrapy/selector/unified.py:83: UserWarning: Selector got both text and root, root is being ignored.
#   super().__init__(text=text, type=st, root=root, **kwargs)
#
# 2023-05-04 19:34:03 [root] INFO: Nombre de property-card pour la ville Rouen : 25
# 2023-05-04 19:34:06 [py.warnings] WARNING: /usr/local/lib/python3.11/site-packages/scrapy/selector/unified.py:83: UserWarning: Selector got both text and root, root is being ignored.
#   super().__init__(text=text, type=st, root=root, **kwargs)
#
# 2023-05-04 19:34:06 [root] INFO: Nombre de property-card pour la ville Le Havre : 25
# 2023-05-04 19:34:09 [py.warnings] WARNING: /usr/local/lib/python3.11/site-packages/scrapy/selector/unified.py:83: UserWarning: Selector got both text and root, root is being ignored.
#   super().__init__(text=text, type=st, root=root, **kwargs)
#
# 2023-05-04 19:34:09 [root] INFO: Nombre de property-card pour la ville Bayeux : 25
# 2023-05-04 19:34:12 [py.warnings] WARNING: /usr/local/lib/python3.11/site-packages/scrapy/selector/unified.py:83: UserWarning: Selector got both text and root, root is being ignored.
#   super().__init__(text=text, type=st, root=root, **kwargs)
#
# 2023-05-04 19:34:12 [root] INFO: Nombre de property-card pour la ville St Malo : 25
# 2023-05-04 19:34:14 [py.warnings] WARNING: /usr/local/lib/python3.11/site-packages/scrapy/selector/unified.py:83: UserWarning: Selector got both text and root, root is being ignored.
#   super().__init__(text=text, type=st, root=root, **kwargs)
#
# 2023-05-04 19:34:14 [root] INFO: Nombre de property-card pour la ville St Malo : 25
# 2023-05-04 19:34:17 [py.warnings] WARNING: /usr/local/lib/python3.11/site-packages/scrapy/selector/unified.py:83: UserWarning: Selector got both text and root, root is being ignored.
#   super().__init__(text=text, type=st, root=root, **kwargs)
#
# 2023-05-04 19:34:17 [root] INFO: Ville : Gorges du Verdon Le nombre de page à scrapper : 5
# 2023-05-04 19:34:19 [py.warnings] WARNING: /usr/local/lib/python3.11/site-packages/scrapy/selector/unified.py:83: UserWarning: Selector got both text and root, root is being ignored.
#   super().__init__(text=text, type=st, root=root, **kwargs)
#
# 2023-05-04 19:34:35 [scrapy.extensions.logstats] INFO: Crawled 778 pages (at 24 pages/min), scraped 710 items (at 7 items/min)
# 2023-05-04 19:34:58 [root] INFO: Nombre de property-card pour la ville Gorges du Verdon : 22
# 2023-05-04 19:35:00 [py.warnings] WARNING: /usr/local/lib/python3.11/site-packages/scrapy/selector/unified.py:83: UserWarning: Selector got both text and root, root is being ignored.
#   super().__init__(text=text, type=st, root=root, **kwargs)
#
# 2023-05-04 19:35:01 [root] INFO: Nombre de property-card pour la ville Gorges du Verdon : 25
# 2023-05-04 19:35:02 [py.warnings] WARNING: /usr/local/lib/python3.11/site-packages/scrapy/selector/unified.py:83: UserWarning: Selector got both text and root, root is being ignored.
#   super().__init__(text=text, type=st, root=root, **kwargs)
#
# 2023-05-04 19:35:02 [root] INFO: Nombre de property-card pour la ville Gorges du Verdon : 25
# 2023-05-04 19:35:07 [py.warnings] WARNING: /usr/local/lib/python3.11/site-packages/scrapy/selector/unified.py:83: UserWarning: Selector got both text and root, root is being ignored.
#   super().__init__(text=text, type=st, root=root, **kwargs)
#
# 2023-05-04 19:35:07 [root] INFO: Nombre de property-card pour la ville Gorges du Verdon : 25
# 2023-05-04 19:35:08 [py.warnings] WARNING: /usr/local/lib/python3.11/site-packages/scrapy/selector/unified.py:83: UserWarning: Selector got both text and root, root is being ignored.
#   super().__init__(text=text, type=st, root=root, **kwargs)
#
# 2023-05-04 19:35:08 [root] INFO: Nombre de property-card pour la ville Gorges du Verdon : 25
# 2023-05-04 19:35:12 [py.warnings] WARNING: /usr/local/lib/python3.11/site-packages/scrapy/selector/unified.py:83: UserWarning: Selector got both text and root, root is being ignored.
#   super().__init__(text=text, type=st, root=root, **kwargs)
#
# 2023-05-04 19:35:35 [scrapy.extensions.logstats] INFO: Crawled 802 pages (at 24 pages/min), scraped 729 items (at 19 items/min)
# 2023-05-04 19:36:35 [scrapy.extensions.logstats] INFO: Crawled 827 pages (at 25 pages/min), scraped 754 items (at 25 items/min)
# 2023-05-04 19:37:35 [scrapy.extensions.logstats] INFO: Crawled 853 pages (at 26 pages/min), scraped 780 items (at 26 items/min)
# 2023-05-04 19:38:35 [scrapy.extensions.logstats] INFO: Crawled 878 pages (at 25 pages/min), scraped 805 items (at 25 items/min)
# 2023-05-04 19:39:35 [scrapy.extensions.logstats] INFO: Crawled 903 pages (at 25 pages/min), scraped 830 items (at 25 items/min)
# 2023-05-04 19:40:35 [scrapy.extensions.logstats] INFO: Crawled 927 pages (at 24 pages/min), scraped 854 items (at 24 items/min)
# 2023-05-04 19:41:35 [scrapy.extensions.logstats] INFO: Crawled 951 pages (at 24 pages/min), scraped 878 items (at 24 items/min)
# 2023-05-04 19:42:35 [scrapy.extensions.logstats] INFO: Crawled 977 pages (at 26 pages/min), scraped 904 items (at 26 items/min)
# 2023-05-04 19:43:35 [scrapy.extensions.logstats] INFO: Crawled 1002 pages (at 25 pages/min), scraped 929 items (at 25 items/min)
# 2023-05-04 19:44:35 [scrapy.extensions.logstats] INFO: Crawled 1024 pages (at 22 pages/min), scraped 951 items (at 22 items/min)
# 2023-05-04 19:45:35 [scrapy.extensions.logstats] INFO: Crawled 1049 pages (at 25 pages/min), scraped 976 items (at 25 items/min)
[scrapy.core.engine] INFO: Closing spider (finished)
# 2023-05-04 20:46:15 [scrapy.extensions.feedexport] INFO: Stored json feed (2405 items) in: data/booking_scrap.json
# 2023-05-04 20:46:15 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 2302747,
#  'downloader/request_count': 2548,
#  'downloader/request_method_count/GET': 2548,
#  'downloader/response_bytes': 822421851,
#  'downloader/response_count': 2548,
#  'downloader/response_status_count/200': 2548,
#  'dupefilter/filtered': 27,
#  'elapsed_time_seconds': 6219.929244,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2023, 5, 4, 20, 46, 15, 3460),
#  'httpcompression/response_bytes': 3555198861,
#  'httpcompression/response_count': 2548,
#  'item_scraped_count': 2405,
#  'log_count/INFO': 327,
#  'log_count/WARNING': 163,
#  'memusage/max': 590807040,
#  'memusage/startup': 172498944,
#  'request_depth_max': 2,
#  'response_received_count': 2548,
#  'scheduler/dequeued': 2548,
#  'scheduler/dequeued/memory': 2548,
#  'scheduler/enqueued': 2548,
#  'scheduler/enqueued/memory': 2548,
#  'start_time': datetime.datetime(2023, 5, 4, 19, 2, 35, 74216)}
# 2023-05-04 20:46:15 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# ### Analyse de la log

# %%
#Analayse de la log : récupération du nombre de pages identifiées par ville dans la log (merci excel)
2023-02-17 19:58:15 [root] INFO: Ville : Mont Saint Michel Le nombre de page à scrapper : 1
2023-02-17 19:58:18 [root] INFO: Ville : St Malo Le nombre de page à scrapper : 4
2023-02-17 19:58:21 [root] INFO: Ville : Bayeux Le nombre de page à scrapper : 3
2023-02-17 19:58:24 [root] INFO: Ville : Le Havre Le nombre de page à scrapper : 3
2023-02-17 19:58:27 [root] INFO: Ville : Rouen Le nombre de page à scrapper : 5
2023-02-17 19:58:29 [root] INFO: Ville : Paris Le nombre de page à scrapper : 1
2023-02-17 19:58:31 [root] INFO: Ville : Amiens Le nombre de page à scrapper : 5
2023-02-17 19:58:34 [root] INFO: Ville : Lille Le nombre de page à scrapper : 4
2023-02-17 19:58:35 [root] INFO: Ville : Strasbourg Le nombre de page à scrapper : 5
2023-02-17 19:58:38 [root] INFO: Ville : Chateau du Haut Koenigsbourg Le nombre de page à scrapper : 5
2023-02-17 19:58:40 [root] INFO: Ville : Colmar Le nombre de page à scrapper : 5
2023-02-17 19:58:43 [root] INFO: Ville : Eguisheim Le nombre de page à scrapper : 1
2023-02-17 19:58:45 [root] INFO: Ville : Besancon Le nombre de page à scrapper : 2
2023-02-17 19:58:47 [root] INFO: Ville : Dijon Le nombre de page à scrapper : 3
2023-02-17 19:58:49 [root] INFO: Ville : Annecy Le nombre de page à scrapper : 5
2023-02-17 19:58:51 [root] INFO: Ville : Grenoble Le nombre de page à scrapper : 2
2023-02-17 19:58:54 [root] INFO: Ville : Lyon Le nombre de page à scrapper : 5
2023-02-17 21:49:18 [root] INFO: Ville : Gorges du Verdon Le nombre de page à scrapper : 4
2023-02-17 21:49:21 [root] INFO: Ville : Bormes les Mimosas Le nombre de page à scrapper : 1
2023-02-17 21:49:24 [root] INFO: Ville : Cassis Le nombre de page à scrapper : 4
2023-02-17 22:52:16 [root] INFO: Ville : Marseille Le nombre de page à scrapper : 5
2023-02-17 22:52:19 [root] INFO: Ville : Aix en Provence Le nombre de page à scrapper : 4
2023-02-17 22:52:21 [root] INFO: Ville : Avignon Le nombre de page à scrapper : 5
2023-02-17 22:52:22 [root] INFO: Ville : Uzes Le nombre de page à scrapper : 2
2023-02-17 22:52:24 [root] INFO: Ville : Nimes Le nombre de page à scrapper : 4
2023-02-17 22:52:27 [root] INFO: Ville : Aigues Mortes Le nombre de page à scrapper : 2
2023-02-17 22:52:29 [root] INFO: Ville : Saintes Maries de la mer Le nombre de page à scrapper : 2
2023-02-17 22:52:33 [root] INFO: Ville : Collioure Le nombre de page à scrapper : 2
2023-02-17 22:52:34 [root] INFO: Ville : Carcassonne Le nombre de page à scrapper : 5
2023-02-17 22:52:37 [root] INFO: Ville : Ariege Le nombre de page à scrapper : 4
2023-02-17 22:52:39 [root] INFO: Ville : Toulouse Le nombre de page à scrapper : 5
2023-02-17 22:52:41 [root] INFO: Ville : Montauban Le nombre de page à scrapper : 2
2023-02-17 22:52:42 [root] INFO: Ville : Biarritz Le nombre de page à scrapper : 5
2023-02-17 22:52:45 [root] INFO: Ville : Bayonne Le nombre de page à scrapper : 1
2023-02-17 22:52:47 [root] INFO: Ville : La Rochelle Le nombre de page à scrapper : 3

#Info : le nombre de page de ce tir a été limité à 5
#En realisant la somme des chiffres, sachant que la dernière page peut récupérer entre 1 et 25 résultats : 
#On devrait avoir entre 2100 et 2975 lignes dans le fichiers.
#Le fichier contient 2444 lignes. Ce qui parrait raisonnablement acceptable. 

#Voyons maintenant le temps d'éxecution : 425minutes soit 7heures.... 
#Un délais de 2 secondes entre chaque requête a été instauré 
    #custom_settings = {
    #    'DOWNLOAD_DELAY': 2, # 10 seconds of delay
    #    'RANDOMIZE_DOWNLOAD_DELAY': True, # By default, when you set DOWNLOAD_DELAY = 2 for example, Scrapy will introduce random delays of between: 
                                          # Lower Limit: 0.5 * DOWNLOAD_DELAY
                                          # Upper Limit: 1.5 * DOWNLOAD_DELAY
    #    'HTTPCACHE_ENABLED': False
    #}
#Voici ce que montre la log: 
#2023-02-18 03:03:14 [scrapy.extensions.logstats] INFO: Crawled 2597 pages (at 2 pages/min), scraped 2443 items (at 2 items/min)
#2597 pages appelées - 1 (la page de départ), comme le temps est randomizé entre 0,5*2sec et 1,5*2 sec on a un temps "d'attente" situé entre : 2596 sec et 7788sec soit 45 minutes et 2h15
#on peut dire environ 1h30 d'attente
#soit 5h de scrapping

# %% [markdown]
# ![alternative text](tab.jpg)

# %% [markdown]
# ### Nettoyage des données Scrappées

# %%
#Import du fichier scrappé en DF
if no_scrap:
    #Utilisation d'un fichier de test local
    df_hotel = pd.read_json("./testing_data/booking_scrap.json")
else:
    df_hotel = pd.read_json("./data/booking_scrap.json")

# %%
#Affichage pour une ville
df_hotel[df_hotel['ville']=='Aix en Provence'].head()
# Out:
#                 ville                                                nom
# 1224  Aix en Provence  Provencal villa with pool and terrace in Aix-e...  \
# 1458  Aix en Provence                        Un Cocon au pays de Cézanne
# 1459  Aix en Provence                 T2 tout confort climatisé de Lilou
# 1460  Aix en Provence             Studio centre historique climatisation
# 1461  Aix en Provence                                   Hôtel le Prieuré
#
#                                                     url     prix  note
# 1224  https://www.booking.com/hotel/fr/provencal-vil...  € 1 704  None  \
# 1458  https://www.booking.com/hotel/fr/appartement-m...    € 964  None
# 1459  https://www.booking.com/hotel/fr/t2-tout-confo...    € 581  None
# 1460  https://www.booking.com/hotel/fr/studio-centre...    € 413  None
# 1461  https://www.booking.com/hotel/fr/le-prieure-ai...    € 326   5,4
#
#        distance_center   latitude  longitude
# 1224  5,3 km du centre  43.480496   5.428179  \
# 1458  7,8 km du centre  43.574879   5.375224
# 1459    1 km du centre  43.523789   5.433065
# 1460  0,6 km du centre  43.530506   5.450253
# 1461  2,1 km du centre  43.542624   5.459127
#
#                                             description
# 1224  Cette villa comprend 3 chambres, un salon, une...
# 1458  Cet appartement comprend une terrasse, une cha...
# 1459  Cet appartement comprend une chambre, une cuis...
# 1460  Cet appartement climatisé comprend une chambre...
# 1461  Les chambres sont équipées d'un téléphone et d...

# %%
#Nettoyage du prix 
df_hotel['prix'] = df_hotel['prix'].apply(lambda x : float(x.replace('€','').replace(' ','')))

# %%
#Nettoyage distance
df_hotel['distance_center'] = df_hotel['distance_center'].str.extract(r'(\d+(?:[.,]*\d*).(?:m|km))').loc[:,0].apply(lambda x : float(str(x).replace(',','.').split('\u00a0')[0]) if str(x).find('km') else float(str(x).replace(',','.').split('\u00a0')[0])/1000 if str(x).find('m') else None)

# %%
#Nettoyage des notes 
df_hotel['note'] = df_hotel['note'].apply(lambda x : float(x.replace(',','.')) if x!= None else None)

# %%
#Affichage pour une ville
df_hotel[df_hotel['ville']=='Aix en Provence'].head()
# Out:
#                 ville                                                nom
# 1224  Aix en Provence  Provencal villa with pool and terrace in Aix-e...  \
# 1458  Aix en Provence                        Un Cocon au pays de Cézanne
# 1459  Aix en Provence                 T2 tout confort climatisé de Lilou
# 1460  Aix en Provence             Studio centre historique climatisation
# 1461  Aix en Provence                                   Hôtel le Prieuré
#
#                                                     url    prix  note
# 1224  https://www.booking.com/hotel/fr/provencal-vil...  1704.0   NaN  \
# 1458  https://www.booking.com/hotel/fr/appartement-m...   964.0   NaN
# 1459  https://www.booking.com/hotel/fr/t2-tout-confo...   581.0   NaN
# 1460  https://www.booking.com/hotel/fr/studio-centre...   413.0   NaN
# 1461  https://www.booking.com/hotel/fr/le-prieure-ai...   326.0   5.4
#
#       distance_center   latitude  longitude
# 1224              5.3  43.480496   5.428179  \
# 1458              7.8  43.574879   5.375224
# 1459              1.0  43.523789   5.433065
# 1460              0.6  43.530506   5.450253
# 1461              2.1  43.542624   5.459127
#
#                                             description
# 1224  Cette villa comprend 3 chambres, un salon, une...
# 1458  Cet appartement comprend une terrasse, une cha...
# 1459  Cet appartement comprend une chambre, une cuis...
# 1460  Cet appartement climatisé comprend une chambre...
# 1461  Les chambres sont équipées d'un téléphone et d...

# %%
#Sauvegarde au format CSV en local
#Si on est en local mode, on écrit les données directement dans le dossier de retour de s3 car on ne fera pas appel a s3
if local_mode:
    df_hotel.to_csv('./data_from_s3/df_hotel.csv')
else:
    df_hotel.to_csv('./data/df_hotel.csv')

# %% [markdown]
# ## Etape 4 : Envoi des données sur Amazon S3

# %%
#Connexion et vérification du bucket
#Init de la session 
if not local_mode:
    session = boto3.Session(aws_access_key_id=aws_key, 
                            aws_secret_access_key=aws_secret)
    #Connexion au service S3
    s3 = session.resource("s3")

    b_exist = False
    # check existence bucket
    for bucket_i in s3.buckets.all():
        if bucket_i.name == bucket_name:
            b_exist = True

    #Si le bucket n'existe pas on le créer
    if not b_exist:
        bucket = s3.create_bucket(Bucket=bucket_name)

    #Upload du fichier issu du scrapping + fichier météo
    s3.Bucket(bucket_name).upload_file('./data/df_hotel.csv', 'df_hotel.csv')
    s3.Bucket(bucket_name).upload_file('./data/df_avg.csv', 'df_avg.csv')
    s3.Bucket(bucket_name).upload_file('./data/df_result.csv', 'df_result.csv')

# %%
#Récupération des fichiers sur s3 dans le dossier data_from_s3 (si on est en local les fichiers ont été créés directement dedans)
if not local_mode:
        s3.Bucket(bucket_name).download_file('df_hotel.csv', './data_from_s3/df_hotel.csv')
        s3.Bucket(bucket_name).download_file('df_avg.csv', './data_from_s3/df_avg.csv')    
        s3.Bucket(bucket_name).download_file('df_result.csv', './data_from_s3/df_result.csv')

# %% [markdown]
# ## Etape 5 : Envoi des données sur Amazon RDS

# %%
#Lecture des fichiers CSV redescendu de S3    
df_avg = pd.read_csv('./data_from_s3/df_avg.csv')
df_result = pd.read_csv('./data_from_s3/df_result.csv')
df_hotel = pd.read_csv('./data_from_s3/df_hotel.csv')

# %%
if rds_mode:
    #Connexion à Amazon RDS
    conn = boto3.client('rds', aws_access_key_id=aws_key,
                        aws_secret_access_key=aws_secret,
                        region_name='eu-west-3')

    #Vérification si la base existe 
    v_exist = False
    response = conn.describe_db_instances()
    for resp in response['DBInstances']:
        if resp['DBName'] == p_DBName:
            v_address = resp['Endpoint']['Address']
            v_port = resp['Endpoint']['Port']
            v_exist=True

    #Création de la base 
    if not v_exist:
        response = conn.create_db_instance(
                AllocatedStorage=10,
                DBName=p_DBName,
                DBInstanceIdentifier=p_DBInstanceIdentifier,
                DBInstanceClass="db.t3.micro",
                Engine="postgres",
                MasterUsername=p_MasterUsername,
                MasterUserPassword=p_MasterUserPassword
            )

        while not v_exist:
            #Attente de la création de la base
            time.sleep(60)
            response = conn.describe_db_instances()
            for resp in response['DBInstances']:
                if resp['DBName'] == p_DBName and resp['DBInstanceStatus'] == 'available':
                    v_address = resp['Endpoint']['Address']
                    v_port = resp['Endpoint']['Port']
                    v_exist=True

# %%
if rds_mode:
    #Connexion via sql alchemy
    DBHOST = v_address
    DBUSER = p_MasterUsername
    DBPASS = p_MasterUserPassword
    DBNAME = p_DBName
    PORT = v_port

    engine = create_engine(f"postgresql+psycopg2://{DBUSER}:{DBPASS}@{DBHOST}/{DBNAME}", echo=True)

# %%
#Préparation du dataframe pour RDS
df_table_hotel = df_hotel[['ville','nom','url','distance_center','latitude','longitude','description']]

# %%
df_table_price_hotel = df_hotel[['ville','nom','url','prix','note']]
df_table_price_hotel['date_arrivee'] = date_sejour
df_table_price_hotel['date_depart'] = date_fin_sejour
# Out:
# /tmp/ipykernel_49646/4290110585.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_table_price_hotel['date_arrivee'] = date_sejour
# /tmp/ipykernel_49646/4290110585.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_table_price_hotel['date_depart'] = date_fin_sejour

# %%
df_table_price_hotel
# Out:
#                   ville                                                nom
# 0     Mont Saint Michel  Mobil-Home Jullouville, 3 pièces, 4 personnes ...  \
# 1               St Malo  Appartement à louer pour la route du rhum 2 ch...
# 2                Bayeux                       Mon Saint-Patrice by Melrose
# 3              Le Havre                               Apart hôtel Le Havre
# 4                 Rouen                          Once upon a time in Rouen
# ...                 ...                                                ...
# 2400             Cassis                                    sous un olivier
# 2401             Cassis  Cassis, le Grand Bleu, triplex vue mer, port p...
# 2402             Cassis                                        LOU CIGALOU
# 2403             Cassis                                         La forlane
# 2404             Cassis            APPARTEMENT VILLAGE CASSIS Options Baby
#
#                                                     url    prix  note
# 0     https://www.booking.com/hotel/fr/maison-jullou...   594.0   9.0  \
# 1     https://www.booking.com/hotel/fr/appartement-a...  1835.0   NaN
# 2     https://www.booking.com/hotel/fr/mon-saint-pat...   856.0   NaN
# 3     https://www.booking.com/hotel/fr/apart-le-havr...   396.0   NaN
# 4     https://www.booking.com/hotel/fr/once-upon-a-t...   219.0   NaN
# ...                                                 ...     ...   ...
# 2400  https://www.booking.com/hotel/fr/sous-un-olivi...   651.0   8.5
# 2401  https://www.booking.com/hotel/fr/le-grand-bleu...  1251.0   9.0
# 2402  https://www.booking.com/hotel/fr/lou-cigalou-c...  1049.0   9.0
# 2403  https://www.booking.com/hotel/fr/la-forlane-ca...   943.0   9.1
# 2404  https://www.booking.com/hotel/fr/cassis-centre...   647.0   9.4
#
#      date_arrivee date_depart
# 0      2023-05-06  2023-05-10
# 1      2023-05-06  2023-05-10
# 2      2023-05-06  2023-05-10
# 3      2023-05-06  2023-05-10
# 4      2023-05-06  2023-05-10
# ...           ...         ...
# 2400   2023-05-06  2023-05-10
# 2401   2023-05-06  2023-05-10
# 2402   2023-05-06  2023-05-10
# 2403   2023-05-06  2023-05-10
# 2404   2023-05-06  2023-05-10
#
# [2405 rows x 7 columns]

# %%
df_result.columns
# Out:
# Index(['Unnamed: 0', 'Ville_Id', 'Ville', 'Longitude_asked', 'Latitude_asked',
#        'Longitude_return', 'Latitude_return', 'Timezone', 'Timezone_offset',
#        'Date', 'Moonset', 'Moonrise', 'Sunset', 'Sunrise', 'moon_phase',
#        'pressure', 'humidity', 'dew_point', 'wind_speed', 'wind_deg',
#        'wind_gust', 'weather.id', 'weather.main', 'weather.description',
#        'weather.icon', 'clouds', 'pop', 'rain', 'uvi', 'temp.day', 'temp.min',
#        'temp.max', 'temp.night', 'temp.eve', 'temp.morn', 'feels_like.day',
#        'feels_like.night', 'feels_like.eve', 'feels_like.morn'],
#       dtype='object')

# %%
if rds_mode:
	#Définition des requetes sql de MAJ or INS des données
	updt_hotel = "update booking_hotel_price tb \
	set prix = tmp.prix, note=tmp.note \
	from booking_hotel_price_tmp tmp \
	where tb.ville = tmp.ville \
	and tb.nom = tmp.nom \
	and tb.url = tmp.url \
	and tb.date_arrivee = tmp.date_arrivee \
	and tb.date_depart = tmp.date_depart"


	ins_hotel = "insert into booking_hotel_price \
	select * \
	from booking_hotel_price_tmp tmp \
	where not exists (select 1 from booking_hotel_price tb \
					where tb.ville = tmp.ville \
					and tb.nom = tmp.nom \
					and tb.url = tmp.url \
					and tb.date_arrivee = tmp.date_arrivee \
					and tb.date_depart = tmp.date_depart)"

	updt_meteo = 'update meteo tb \
	set \
	"Longitude_asked" = tmp."Longitude_asked", \
	"Latitude_asked" = tmp."Latitude_asked", \
	"Longitude_return" = tmp."Longitude_return", \
	"Latitude_return" = tmp."Latitude_return", \
	"Timezone" = tmp."Timezone", \
	"Timezone_offset" = tmp."Timezone_offset", \
	"Moonset" = tmp."Moonset", \
	"Moonrise" = tmp."Moonrise", \
	"Sunset" = tmp."Sunset", \
	"Sunrise" = tmp."Sunrise", \
	"moon_phase" = tmp."moon_phase", \
	"pressure" = tmp."pressure", \
	"humidity" = tmp."humidity", \
	"dew_point" = tmp."dew_point", \
	"wind_speed" = tmp."wind_speed", \
	"wind_deg" = tmp."wind_deg", \
	"wind_gust" = tmp."wind_gust", \
	"weather.id" = tmp."weather.id", \
	"weather.main" = tmp."weather.main", \
	"weather.description" = tmp."weather.description", \
	"weather.icon" = tmp."weather.icon", \
	"clouds" = tmp."clouds", \
	"pop" = tmp."pop", \
	"uvi" = tmp."uvi", \
	"temp.day" = tmp."temp.day", \
	"temp.min" = tmp."temp.min", \
	"temp.max" = tmp."temp.max", \
	"temp.night" = tmp."temp.night", \
	"temp.eve" = tmp."temp.eve", \
	"temp.morn" = tmp."temp.morn", \
	"feels_like.day" = tmp."feels_like.day", \
	"feels_like.night" = tmp."feels_like.night", \
	"feels_like.eve" = tmp."feels_like.eve", \
	"feels_like.morn" = tmp."feels_like.morn", \
	"rain" = tmp."rain", \
	"snow" = tmp."snow" \
	from meteo_tmp tmp  \
	where tb."Ville" = tmp."Ville"  \
	and tb."Date" = tmp."Date"' 

	ins_meteo = 'insert into meteo \
	select * \
	from meteo_tmp tmp  \
	where not exists (select 1 from meteo tb \
					where tb."Ville" = tmp."Ville" \
					and tb."Date" = tmp."Date")'

# %%
if rds_mode:
    # Connexion à la BDD
    conn = engine.connect()
    insp = inspect(engine)

    #Si on est en mode full (pas uniquement la mise à jour des prix) on créer la table à partir du DF 
    if (not insp.has_table('booking_hotel')) and mode == 'full':
        df_table_hotel.to_sql('booking_hotel',conn)
        df_table_price_hotel.to_sql('booking_hotel_price',conn)
        df_result.to_sql('meteo',conn)
    elif insp.has_table('booking_hotel') and mode == 'full':
        #Suppression des tables existantes
        stmt = text("DROP TABLE booking_hotel")
        result = conn.execute(stmt)
        stmt = text("DROP TABLE booking_hotel_price")
        result = conn.execute(stmt)
        stmt = text("DROP TABLE meteo")
        result = conn.execute(stmt)
        #Création à partir des nouvelles data récupérées
        df_table_hotel.to_sql('booking_hotel',conn)
        df_table_price_hotel.to_sql('booking_hotel_price',conn)
        df_result.to_sql('meteo',conn)
    #Cas ou on ne fait que de la mise à jour, on considère que les données des hotels n'ont pas évolué on met à jour la table price et la table météo
    elif insp.has_table('booking_hotel') and mode != 'full':
        #Création de table temporaire avec les données du moments
        df_table_price_hotel.to_sql('booking_hotel_price_tmp',conn)
        df_result.to_sql('meteo_tmp',conn)
        #mise à jour des Data (update insert)
        stmt = text(updt_hotel)
        result = conn.execute(stmt)
        stmt = text(updt_meteo)
        result = conn.execute(stmt)
        stmt = text(ins_hotel)
        result = conn.execute(stmt)
        stmt = text(ins_meteo)
        result = conn.execute(stmt)
        stmt = text("DROP TABLE meteo_tmp")
        result = conn.execute(stmt)
        stmt = text("DROP TABLE booking_hotel_price_tmp")
        result = conn.execute(stmt)

    conn.commit()
# Out:
# 2023-05-05 08:00:40,497 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2023-05-05 08:00:40,498 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-05-05 08:00:40,539 INFO sqlalchemy.engine.Engine select current_schema()
# 2023-05-05 08:00:40,540 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-05-05 08:00:40,578 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2023-05-05 08:00:40,579 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-05-05 08:00:40,772 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-05-05 08:00:40,773 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-05-05 08:00:40,774 INFO sqlalchemy.engine.Engine [generated in 0.00239s] {'table_name': 'booking_hotel', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2023-05-05 08:00:40,820 INFO sqlalchemy.engine.Engine ROLLBACK
# 2023-05-05 08:00:40,838 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-05-05 08:00:40,839 INFO sqlalchemy.engine.Engine DROP TABLE booking_hotel
# 2023-05-05 08:00:40,839 INFO sqlalchemy.engine.Engine [generated in 0.00090s] {}
# 2023-05-05 08:00:40,895 INFO sqlalchemy.engine.Engine DROP TABLE booking_hotel_price
# 2023-05-05 08:00:40,896 INFO sqlalchemy.engine.Engine [generated in 0.00119s] {}
# 2023-05-05 08:00:40,921 INFO sqlalchemy.engine.Engine DROP TABLE meteo
# 2023-05-05 08:00:40,922 INFO sqlalchemy.engine.Engine [generated in 0.00150s] {}
# 2023-05-05 08:00:40,945 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-05-05 08:00:40,945 INFO sqlalchemy.engine.Engine [cached since 0.1733s ago] {'table_name': 'booking_hotel', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2023-05-05 08:00:40,965 INFO sqlalchemy.engine.Engine
# CREATE TABLE booking_hotel (
# 	index BIGINT,
# 	ville TEXT,
# 	nom TEXT,
# 	url TEXT,
# 	distance_center FLOAT(53),
# 	latitude FLOAT(53),
# 	longitude FLOAT(53),
# 	description TEXT
# )
#
#
# 2023-05-05 08:00:40,965 INFO sqlalchemy.engine.Engine [no key 0.00053s] {}
# 2023-05-05 08:00:41,018 INFO sqlalchemy.engine.Engine CREATE INDEX ix_booking_hotel_index ON booking_hotel (index)
# 2023-05-05 08:00:41,020 INFO sqlalchemy.engine.Engine [no key 0.00114s] {}
# 2023-05-05 08:00:41,056 INFO sqlalchemy.engine.Engine INSERT INTO booking_hotel (index, ville, nom, url, distance_center, latitude, longitude, description) VALUES (%(index__0)s, %(ville__0)s, %(nom__0)s, %(url__0)s, %(distance_center__0)s, %(latitude__0)s, %(longitude__0)s, %(description__0)s), (%(index ... 147877 characters truncated ... %(url__999)s, %(distance_center__999)s, %(latitude__999)s, %(longitude__999)s, %(description__999)s)
INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-05-05 08:00:41,465 INFO sqlalchemy.engine.Engine [cached since 0.6925s ago] {'table_name': 'booking_hotel_price', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2023-05-05 08:00:41,485 INFO sqlalchemy.engine.Engine
# CREATE TABLE booking_hotel_price (
# 	index BIGINT,
# 	ville TEXT,
# 	nom TEXT,
# 	url TEXT,
# 	prix FLOAT(53),
# 	note FLOAT(53),
# 	date_arrivee TEXT,
# 	date_depart TEXT
# )
#
#
# 2023-05-05 08:00:41,486 INFO sqlalchemy.engine.Engine [no key 0.00105s] {}
# 2023-05-05 08:00:41,529 INFO sqlalchemy.engine.Engine CREATE INDEX ix_booking_hotel_price_index ON booking_hotel_price (index)
# 2023-05-05 08:00:41,529 INFO sqlalchemy.engine.Engine [no key 0.00057s] {}
# 2023-05-05 08:00:41,564 INFO sqlalchemy.engine.Engine INSERT INTO booking_hotel_price (index, ville, nom, url, prix, note, date_arrivee, date_depart) VALUES (%(index__0)s, %(ville__0)s, %(nom__0)s, %(url__0)s, %(prix__0)s, %(note__0)s, %(date_arrivee__0)s, %(date_depart__0)s), (%(index__1)s, %(ville__1) ... 135871 characters truncated ... nom__999)s, %(url__999)s, %(prix__999)s, %(note__999)s, %(date_arrivee__999)s, %(date_depart__999)s)
# 2023-05-05 08:00:41,565 INFO sqlalchemy.engine.Engine [generated in 0.00696s (insertmanyvalues) 1/3 (unordered)] {'note__0': 9.0, 'index__0': 0, 'ville__0': 'Mont Saint Michel', 'url__0': 'https://www.booking.com/hotel/fr/maison-jullouville-3-pieces-4-personnes-fr-1-361a-23.fr.html', 'nom__0': 'Mobil-Home Jullouville, 3 pièces, 4 personnes - FR-1-361A-23', 'prix__0': 594.0, 'date_depart__0': '2023-05-10', 'date_arrivee__0': '2023-05-06', 'note__1': None, 'index__1': 1, 'ville__1': 'St Malo', 'url__1': 'https://www.booking.com/hotel/fr/appartement-a-louer-pour-la-route-du-rhum.fr.html', 'nom__1': 'Appartement à louer pour la route du rhum 2 chambres', 'prix__1': 1835.0, 'date_depart__1': '2023-05-10', 'date_arrivee__1': '2023-05-06', 'note__2': None, 'index__2': 2, 'ville__2': 'Bayeux', 'url__2': 'https://www.booking.com/hotel/fr/mon-saint-patrice-by-melrose.fr.html', 'nom__2': 'Mon Saint-Patrice by Melrose', 'prix__2': 856.0, 'date_depart__2': '2023-05-10', 'date_arrivee__2': '2023-05-06', 'note__3': None, 'index__3': 3, 'ville__3': 'Le Havre', 'url__3': 'https://www.booking.com/hotel/fr/apart-le-havre.fr.html', 'nom__3': 'Apart hôtel Le Havre', 'prix__3': 396.0, 'date_depart__3': '2023-05-10', 'date_arrivee__3': '2023-05-06', 'note__4': None, 'index__4': 4, 'ville__4': 'Rouen', 'url__4': 'https://www.booking.com/hotel/fr/once-upon-a-time-in-rouen.fr.html', 'nom__4': 'Once upon a time in Rouen', 'prix__4': 219.0, 'date_
so Calanques Plage', 'prix__5': 604.0, 'date_depart__5': '2023-05-10', 'date_arrivee__5': '2023-05-06', 'note__6': 7.8, 'index__6': 2006 ... 3140 parameters truncated ... 'date_depart__398': '2023-05-10', 'date_arrivee__398': '2023-05-06', 'note__399': 8.6, 'index__399': 2399, 'ville__399': 'Cassis', 'url__399': 'https://www.booking.com/hotel/fr/le-13-cassis.fr.html', 'nom__399': 'Le 13', 'prix__399': 682.0, 'date_depart__399': '2023-05-10', 'date_arrivee__399': '2023-05-06', 'note__400': 8.5, 'index__400': 2400, 'ville__400': 'Cassis', 'url__400': 'https://www.booking.com/hotel/fr/sous-un-olivier.fr.html', 'nom__400': 'sous un olivier', 'prix__400': 651.0, 'date_depart__400': '2023-05-10', 'date_arrivee__400': '2023-05-06', 'note__401': 9.0, 'index__401': 2401, 'ville__401': 'Cassis', 'url__401': 'https://www.booking.com/hotel/fr/le-grand-bleu-cassis1.fr.html', 'nom__401': 'Cassis, le Grand Bleu, triplex vue mer, port plage 10mn à pieds', 'prix__401': 1251.0, 'date_depart__401': '2023-05-10', 'date_arrivee__401': '2023-05-06', 'note__402': 9.0, 'index__402': 2402, 'ville__402': 'Cassis', 'url__402': 'https://www.booking.com/hotel/fr/lou-cigalou-cassis.fr.html', 'nom__402': 'LOU CIGALOU', 'prix__402': 1049.0, 'date_depart__402': '2023-05-10', 'date_arrivee__402': '2023-05-06', 'note__403': 9.1, 'index__403': 2403, 'ville__403': 'Cassis', 'url__403': 'https://www.booking.com/hotel/fr/la-forlane-cassis1.fr.html', 'nom__403': 'La forlane', 'prix__403': 943.0, 'date_depart__403': '2023-05-10', 'date_arrivee__403': '2023-05-06', 'note__404': 9.4, 'index__404': 2404, 'ville__404': 'Cassis', 'url__404': 'https://www.booking.com/hotel/fr/cassis-centre-neuf-72-m2-clim-et-place-privee.fr.html', 'nom__404': 'APPARTEMENT VILLAGE CASSIS Options Baby', 'prix__404': 647.0, 'date_depart__404': '2023-05-10', 'date_arrivee__404': '2023-05-06'}
# 2023-05-05 08:00:41,735 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-05-05 08:00:41,735 INFO sqlalchemy.engine.Engine [cached since 0.9631s ago] {'table_name': 'meteo', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2023-05-05 08:00:41,755 INFO sqlalchemy.engine.Engine
# CREATE TABLE meteo (
# 	index BIGINT,
# 	"Unnamed: 0" BIGINT,
# 	"Ville_Id" BIGINT,
# 	"Ville" TEXT,
# 	"Longitude_asked" FLOAT(53),
# 	"Latitude_asked" FLOAT(53),
# 	"Longitude_return" FLOAT(53),
# 	"Latitude_return" FLOAT(53),
# 	"Timezone" TEXT,
# 	"Timezone_offset" BIGINT,
# 	"Date" TEXT,
# 	"Moonset" TEXT,
# 	"Moonrise" TEXT,
# 	"Sunset" TEXT,
# 	"Sunrise" TEXT,
# 	moon_phase FLOAT(53),
# 	pressure BIGINT,
# 	humidity BIGINT,
# 	dew_point FLOAT(53),
# 	wind_speed FLOAT(53),
# 	wind_deg BIGINT,
# 	wind_gust FLOAT(53),
# 	"weather.id" BIGINT,
# 	"weather.main" TEXT,
# 	"weather.description" TEXT,
# 	"weather.icon" TEXT,
# 	clouds BIGINT,
# 	pop FLOAT(53),
# 	rain FLOAT(53),
# 	uvi FLOAT(53),
# 	"temp.day" FLOAT(53),
# 	"temp.min" FLOAT(53),
# 	"temp.max" FLOAT(53),
# 	"temp.night" FLOAT(53),
# 	"temp.eve" FLOAT(53),
# 	"temp.morn" FLOAT(53),
# 	"feels_like.day" FLOAT(53),
# 	"feels_like.night" FLOAT(53),
# 	"feels_like.eve" FLOAT(53),
# 	"feels_like.morn" FLOAT(53)
# )
#
#
# 2023-05-05 08:00:41,755 INFO sqlalchemy.engine.Engine [no key 0.00076s] {}
# 2023-05-05 08:00:41,786 INFO sqlalchemy.engine.Engine CREATE INDEX ix_meteo_index ON meteo (index)
# 2023-05-05 08:00:41,786 INFO sqlalchemy.engine.Engine [no key 0.00050s] {}
# 2023-05-05 08:00:41,817 INFO sqlalchemy.engine.Engine INSERT INTO meteo (index, "Unnamed: 0", "Ville_Id", "Ville", "Longitude_asked", "Latitude_asked", "Longitude_return", "Latitude_return", "Timezone", "Timezone_offset", "Date", "Moonset", "Moonrise", "Sunset", "Sunrise", moon_phase, pressure, humidity ... 227074 characters truncated ... feels_like_day__279)s, %(feels_like_night__279)s, %(feels_like_eve__279)s, %(feels_like_morn__279)s)
# 2023-05-05 08:00:41,817 INFO sqlalchemy.engine.Engine [generated in 0.00320s (insertmanyvalues) 1/1 (unordered)] {'dew_point__0': 13.35, 'Timezone__0': 'Europe/Paris', 'feels_like_day__0': 17.75, 'wind_deg__0': 212, 'Date__0': '2023-05-04 12:00:00', 'Sunset__0': '2023-05-04 19:23:44', 'humidity__0': 76, 'Moonrise__0': '2023-05-04 18:12:00', 'Longitude_asked__0': -1.511459954959514, 'uvi__0': 5.16, 'Timezone_offset__0': 7200, 'feels_like_eve__0': 16.04, 'Latitude_return__0': 48.636, 'Ville_Id__0': 0, 'UnnamedC_0__0': 0, 'wind_speed__0': 8.5, 'feels_like_morn__0': 13.49, 'index__0': 0, 'weather_description__0': 'légère pluie', 'pop__0': 1.0, 'moon_phase__0': 0.45, 'temp_eve__0': 16.15, 'temp_day__0': 17.92, 'pressure__0': 1013, 'feels_like_night__0': 14.42, 'weather_main__0': 'Rain', 'Moonset__0': '2023-05-04 04:10:00', 'Longitude_return__0': -1.5115, 'Latitude_asked__0': 48.6359541, 'weather_icon__0': '10d', 'clouds__0': 28, 'temp_max__0': 18.66, 'wind_gust__0': 14.27, 'temp_morn__0': 13.97, 'Ville__0': 'Mont Saint Michel', 'rain__0': 3.46, 'temp_min__0': 13.97, 'Sunrise__0': '2023-05-04 04:41:52', 'weather_id__0': 500, 'temp_night__0': 14.56, 'dew_point__1': 11.11, 'Timezone__1': 'Europe/Paris', 'feels_like_day__1': 17.03, 'wind_deg__1': 222, 'Date__1': '2023-05-05 12:00:00', 'Sunset__1': '2023-05-05 19:25:11', 'humidity__1': 67, 'Moonrise__1': '2023-05-05 19:31:00', 'Longitude_asked__1': -1.511459954959514, 'uvi__1': 5.68 ... 11100 parameters truncated ... 'clouds__278': 99, 'temp_max__278': 15.72, 'wind_gust__278': 10.37, 'temp_morn__278': 13.91, 'Ville__278': 'La Rochelle', 'rain__278': 1.47, 'temp_min__278': 12.61, 'Sunrise__278': '2023-05-10 04:38:50', 'weather_id__278': 500, 'temp_night__278': 12.61, 'dew_point__279': 8.45, 'Timezone__279': 'Europe/Paris', 'feels_like_day__279': 13.69, 'wind_deg__279': 314, 'Date__279': '2023-05-11 12:00:00', 'Sunset__279': '2023-05-11 19:24:32', 'humidity__279': 67, 'Moonrise__279': '2023-05-11 01:01:00', 'Longitude_asked__279': -1.1520434, 'uvi__279': 3.0, 'Timezone_offset__279': 7200, 'feels_like_eve__279': 14.02, 'Latitude_return__279': 46.1591, 'Ville_Id__279': 34, 'UnnamedC_0__279': 279, 'wind_speed__279': 7.85, 'feels_like_morn__279': 10.87, 'index__279': 279, 'weather_description__279': 'légère pluie', 'pop__279': 0.49, 'moon_phase__279': 0.71, 'temp_eve__279': 14.48, 'temp_day__279': 14.44, 'pressure__279': 1023, 'feels_like_night__279': 12.19, 'weather_main__279': 'Rain', 'Moonset__279': '2023-05-11 09:29:00', 'Longitude_return__279': -1.152, 'Latitude_asked__279': 46.1591126, 'weather_icon__279': '10d', 'clouds__279': 65, 'temp_max__279': 14.95, 'wind_gust__279': 9.44, 'temp_morn__279': 11.52, 'Ville__279': 'La Rochelle', 'rain__279': 2.01, 'temp_min__279': 10.62, 'Sunrise__279': '2023-05-11 04:37:31', 'weather_id__279': 500, 'temp_night__279': 12.72}
# 2023-05-05 08:00:41,877 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ## Etape 6 : Lecture des données sur Amazon RDS

# %%
if rds_mode:
    #Récupération des dataframes depuis RDS
    rq = "SELECT \
    hti.ville ville, \
    hti.nom nom, \
    hti.url url, \
    hti.distance_center distance_center, \
    hti.latitude latitude, \
    hti.longitude longitude, \
    hti.description description, \
    htip.prix prix, \
    htip.note note \
    from booking_hotel hti \
    inner join booking_hotel_price htip on htip.ville = hti.ville \
    and htip.url = hti.url \
    and htip.nom = hti.nom"

    rq2 = 'SELECT \
    MAX("Ville") "Ville", \
    MAX("Latitude_return") "Latitude_return", \
    MAX("Longitude_return") "Longitude_return", \
    AVG("humidity") "avg_humidity", \
    AVG("wind_speed") "avg_wind_speed", \
    AVG("clouds") "avg_clouds", \
    AVG("pop") "avg_pop", \
    SUM("rain") "sum_rain", \
    AVG("feels_like.day") "avg_feel_temp" \
    FROM meteo  \
    where TO_TIMESTAMP("Date", \'YYYY-MM-DD\') BETWEEN TO_TIMESTAMP(\''+date_sejour+'\', \'YYYY-MM-DD\') and TO_TIMESTAMP(\''+date_fin_sejour+'\', \'YYYY-MM-DD\') \
    GROUP BY "Ville"'

    df_rds_hotel = pd.read_sql(rq,conn)
    df_rds_meteo = pd.read_sql(rq2,conn)
    df_rds_meteo = df_rds_meteo.fillna(0)
    #Sauvegarde des fichiers
    df_rds_hotel.to_csv('./testing_data/df_rds_hotel.csv')
    df_rds_meteo.to_csv('./testing_data/df_rds_meteo.csv')

else:
    #Lecture des fichiers CSV de sauvegarde
    df_rds_hotel = pd.read_csv('./testing_data/df_rds_hotel.csv')
    df_rds_meteo = pd.read_csv('./testing_data/df_rds_meteo.csv')
# Out:
# 2023-05-05 08:00:50,719 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-05-05 08:00:50,719 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-05-05 08:00:50,720 INFO sqlalchemy.engine.Engine [cached since 9.948s ago] {'table_name': 'SELECT hti.ville ville, hti.nom nom, hti.url url, hti.distance_center distance_center, hti.latitude latitude, hti.longitude longitude, hti.descriptio ... (27 characters truncated) ... ix, htip.note note from booking_hotel hti inner join booking_hotel_price htip on htip.ville = hti.ville and htip.url = hti.url and htip.nom = hti.nom', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2023-05-05 08:00:50,757 INFO sqlalchemy.engine.Engine SELECT hti.ville ville, hti.nom nom, hti.url url, hti.distance_center distance_center, hti.latitude latitude, hti.longitude longitude, hti.description description, htip.prix prix, htip.note note from booking_hotel hti inner join booking_hotel_price htip on htip.ville = hti.ville and htip.url = hti.url and htip.nom = hti.nom
# 2023-05-05 08:00:50,757 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-05-05 08:00:50,903 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-05-05 08:00:50,904 INFO sqlalchemy.engine.Engine [cached since 10.13s ago] {'table_name': 'SELECT MAX("Ville") "Ville", MAX("Latitude_return") "Latitude_return", MAX("Longitude_return") "Longitude_return", AVG("humidity") "avg_humidity", AV ... (170 characters truncated) ... ESTAMP("Date", \'YYYY-MM-DD\') BETWEEN TO_TIMESTAMP(\'2023-05-06\', \'YYYY-MM-DD\') and TO_TIMESTAMP(\'2023-05-10\', \'YYYY-MM-DD\') GROUP BY "Ville"', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2023-05-05 08:00:50,921 INFO sqlalchemy.engine.Engine SELECT MAX("Ville") "Ville", MAX("Latitude_return") "Latitude_return", MAX("Longitude_return") "Longitude_return", AVG("humidity") "avg_humidity", AVG("wind_speed") "avg_wind_speed", AVG("clouds") "avg_clouds", AVG("pop") "avg_pop", SUM("rain") "sum_rain", AVG("feels_like.day") "avg_feel_temp" FROM meteo  where TO_TIMESTAMP("Date", 'YYYY-MM-DD') BETWEEN TO_TIMESTAMP('2023-05-06', 'YYYY-MM-DD') and TO_TIMESTAMP('2023-05-10', 'YYYY-MM-DD') GROUP BY "Ville"
# 2023-05-05 08:00:50,921 INFO sqlalchemy.engine.Engine [raw sql] {}

# %%
#Création d'une colonne avec note réagencée pour le graphique (on utilise l'exponentiel pour accentuer les écarts de notes)
df_rds_hotel['note_aff'] = df_rds_hotel['note'].apply(lambda x : int(np.exp(x)/100) if not np.isnan(x) else np.exp(0.5))

# %%
#Création d'une colonne avec une description formatée pour le graphique 
def cut(chaine,taille):
    nb_mots = 0
    chaine_finale  = ''
    if chaine.find('Vous pouvez bénéficier d\'une réduction Gen') != -1 and chaine.find('pour économiser.')!=-1:
       chaine = chaine[chaine.find('pour économiser.')+16:]
    for i in chaine.split(' '):
        nb_mots += 1
        chaine_finale += i+' '
        if nb_mots == taille:
         chaine_finale += '</br> '
         nb_mots = 0
    return chaine_finale

df_rds_hotel['description_aff'] = df_rds_hotel['description'].apply(lambda x : cut(x,10) if x != None else x)

# %%
#Récupération des 20 Hotels les moins chers par ville 
df_rds_hotel_20  = df_rds_hotel
df_rds_hotel_20['rankbycity'] = df_rds_hotel_20.groupby("ville")["prix"].rank(method="dense", ascending=True)
mask = df_rds_hotel_20['rankbycity']< 21
df_rds_hotel_20 = df_rds_hotel_20[mask].sort_values(by=['ville','rankbycity'])

# %%
#Récupération des 5 destinations avec la meilleurs météo 
df_rds_meteo_5  = df_rds_meteo
#on créé un rank par mesure importante (temperature et pluie) avec des coefficients d'importance ici la pluie est 3 fois plus importante que la temperature
df_rds_meteo_5['rankbytemp'] = 2.5*df_rds_meteo_5["avg_feel_temp"].rank(method="dense", ascending=False)
df_rds_meteo_5['rankbyrain'] = 7.5*df_rds_meteo_5["sum_rain"].rank(method="dense", ascending=True)
#on fait la moyenne de ces notes
df_rds_meteo_5['notemoyenne'] = df_rds_meteo_5[['rankbytemp','rankbyrain']].mean(axis=1)
#On prend les 5 premières villes 
df_rds_meteo_5 = df_rds_meteo_5.sort_values(by='notemoyenne').iloc[0:5,:]

# %%
df_rds_hotel_20
# Out:
#               ville                                              nom
# 2195  Aigues Mortes  Noemys Aigues-Mortes - ex Mona Lisa Royal Hôtel  \
# 2202  Aigues Mortes                    Résidence Odalys Fleur de Sel
# 2193  Aigues Mortes           La Suite du Mas Lauseta - clim et park
# 2207  Aigues Mortes                           La maison sur la place
# 2206  Aigues Mortes                        Hotel Canal Aigues Mortes
# ...             ...                                              ...
# 1433           Uzes                           Le Mas des Alexandrins
# 1421           Uzes                       Uzes duplex atypique calme
# 1430           Uzes                                      Le Sabotier
# 1429           Uzes                                     Villa Maélie
# 1426           Uzes                                        Chez Vous
#
#                                                     url  distance_center
# 2195  https://www.booking.com/hotel/fr/le-royal-hote...              1.2  \
# 2202  https://www.booking.com/hotel/fr/residence-oda...              1.2
# 2193  https://www.booking.com/hotel/fr/la-maison-d-a...              0.6
# 2207  https://www.booking.com/hotel/fr/la-maison-sur...            250.0
# 2206  https://www.booking.com/hotel/fr/canal-aigues-...              0.8
# ...                                                 ...              ...
# 1433  https://www.booking.com/hotel/fr/le-mas-des-al...              1.9
# 1421  https://www.booking.com/hotel/fr/uzes-duplex-a...             10.0
# 1430  https://www.booking.com/hotel/fr/le-sabotier.f...            150.0
# 1429  https://www.booking.com/hotel/fr/villa-maelie....              4.5
# 1426  https://www.booking.com/hotel/fr/chez-vous-uze...            200.0
#
#        latitude  longitude                                        description
# 2195  43.576396   4.197818  Certaines chambres offrent une vue sur la pisc...  \
# 2202  43.574094   4.179246  Vous pouvez bénéficier d'une réduction Genius ...
# 2193  43.567424   4.198007  L'appartement comprend une télévision à écran ...
# 2207  43.565873   4.192959  Cette maison de vacances climatisée comprend 2...
# 2206  43.572988   4.194825  Vous pouvez bénéficier d'une réduction Genius ...
# ...         ...        ...                                                ...
# 1433  43.995892   4.427467  Leur salle de bains privative est pourvue d'un...
# 1421  44.012052   4.419612  Vous pouvez bénéficier d'une réduction Genius ...
# 1430  44.011359   4.418263  Vous pouvez bénéficier d'une réduction Genius ...
# 1429  44.051169   4.403877  Cette maison de vacances comprend 3 chambres, ...
# 1426  44.013612   4.417988  Cet appartement comprend 2 chambres, une télév...
#
#         prix  note    note_aff
# 2195   399.0   7.0   10.000000  \
# 2202   459.0   8.3   40.000000
# 2193   460.0   NaN    1.648721
# 2207   473.0   8.5   49.000000
# 2206   491.0   8.5   49.000000
# ...      ...   ...         ...
# 1433   745.0   9.4  120.000000
# 1421   788.0   7.8   24.000000
# 1430   797.0   8.9   73.000000
# 1429   894.0   8.9   73.000000
# 1426  1049.0   8.0   29.000000
#
#                                         description_aff  rankbycity
# 2195  Certaines chambres offrent une vue sur la pisc...         1.0
# 2202  Répartis en petits duplex, tous les appartemen...         2.0
# 2193  L'appartement comprend une télévision à écran ...         3.0
# 2207  Cette maison de vacances climatisée comprend 2...         4.0
# 2206  Toutes les chambres de cet hôtel 3 étoiles son...         5.0
# ...                                                 ...         ...
# 1433  Leur salle de bains privative est pourvue d'un...        16.0
# 1421  Cet appartement climatisé comprend 2 chambres,...        17.0
# 1430  Il comprend également une télévision par câble...        18.0
# 1429  Cette maison de vacances comprend 3 chambres, ...        19.0
# 1426  Cet appartement comprend 2 chambres, une télév...        20.0
#
# [762 rows x 12 columns]

# %%
df_rds_meteo_5
# Out:
#                  Ville  Latitude_return  Longitude_return  avg_humidity
# 10  Bormes les Mimosas          43.1507            6.3419          57.0  \
# 1      Aix en Provence          43.5298            5.4475          38.0
# 24           Marseille          43.2962            5.3700          53.4
# 12              Cassis          43.2140            5.5396          54.8
# 27               Nimes          43.8374            4.3601          39.0
#
#     avg_wind_speed  avg_clouds  avg_pop  sum_rain  avg_feel_temp  rankbytemp
# 10           5.096        57.8    0.176      0.59         20.544        22.5  \
# 1            5.936        49.8    0.254      2.32         23.070        10.0
# 24           8.092        48.2    0.246      1.57         20.580        20.0
# 12           7.638        49.6    0.182      1.01         20.284        27.5
# 27           6.058        51.6    0.584      5.97         24.548         2.5
#
#     rankbyrain  notemoyenne
# 10         7.5        15.00
# 1         30.0        20.00
# 24        22.5        21.25
# 12        15.0        21.25
# 27        45.0        23.75

# %%
#filtre du Dataframe Hotel sur les 5 villes les plus chaudes
mask = df_rds_hotel_20['ville'].isin(df_rds_meteo_5['Ville'].to_list())
df_rds_hotel_20_in_5 = df_rds_hotel_20[mask]

# %% [markdown]
# ## Etape 7 : Traçage des graphiques

# %%
#Traçage du graphique météo

fig = go.Figure()

#Définition d'une échelle de couleur pour les températures
echelle_couleur=[[0.0, "rgb(49,54,149)"],
                [0.1111111111111111, "rgb(69,117,180)"],
                [0.2222222222222222, "rgb(116,173,209)"],
                [0.3333333333333333, "rgb(171,217,233)"],
                [0.4444444444444444, "rgb(224,243,248)"],
                [0.5555555555555556, "rgb(254,224,144)"],
                [0.6666666666666666, "rgb(253,174,97)"],
                [0.7777777777777778, "rgb(244,109,67)"],
                [0.8888888888888888, "rgb(215,48,39)"],
                [1.0,  "rgb(165,0,38)"]]


fig.add_trace(
    go.Scattermapbox(
        lon = df_rds_meteo_5['Longitude_return'],
        lat = df_rds_meteo_5['Latitude_return'],
        customdata=df_rds_meteo_5[['avg_humidity','avg_wind_speed','avg_clouds','avg_pop','sum_rain','avg_feel_temp']].values.tolist(),
        marker = dict(
            size = df_rds_meteo_5['avg_feel_temp']*100,
            sizemode = 'area',
            color=df_rds_meteo_5['avg_feel_temp'],
            colorbar=dict(
                    title="Temperature"
                    ),
            colorscale=echelle_couleur
        ),
        name = 'Ville',
        text = df_rds_meteo_5['Ville'],
        #hoverinfo='none'
        hovertemplate="<b>Ville :</b> %{text} <br> \
<b>Température ressentie en journée :</b> %{customdata[5]} <br> \
<b>% Humidité :</b> %{customdata[0]} <br> \
<b>Vitesse du vent :</b> %{customdata[1]} <br> \
<b>% de nuages :</b> %{customdata[2]} <br> \
<b>Probabilité de pluie :</b> %{customdata[3]} <br> \
<b>Précipitation(mm) :</b> %{customdata[4]} <br>"
   )
)

fig.update_layout(
        width=1000,
        height=1000,
        mapbox=dict(
            accesstoken=mapbox_access_token,
            bearing=0,
            center=go.layout.mapbox.Center(
                lat=47,
                lon=2
        ),
        zoom=5.1,
        pitch=0
))

fig.show()
# Out:
# <div>                            <div id="3b57591e-710d-4986-813d-c8cd97580133" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3b57591e-710d-4986-813d-c8cd97580133")) {                    Plotly.newPlot(                        "3b57591e-710d-4986-813d-c8cd97580133",                        [{"customdata":[[57.0,5.095999999999999,57.8,0.176,0.59,20.544000000000004],[38.0,5.936,49.8,0.254,2.32,23.07],[53.4,8.092,48.2,0.246,1.57,20.580000000000002],[54.8,7.638000000000001,49.6,0.18200000000000002,1.01,20.284],[39.0,6.058,51.6,0.5840000000000001,5.97,24.548000000000002]],"hovertemplate":"<b>Ville :</b> %{text} <br> <b>Temp\u00e9rature ressentie en journ\u00e9e :</b> %{customdata[5]} <br> <b>% Humidit\u00e9 :</b> %{customdata[0]} <br> <b>Vitesse du vent :</b> %{customdata[1]} <br> <b>% de nuages :</b> %{customdata[2]} <br> <b>Probabilit\u00e9 de pluie :</b> %{customdata[3]} <br> <b>Pr\u00e9cipitation(mm) :</b> %{customdata[4]} <br>","lat":[43.1507,43.5298,43.2962,43.214,43.8374],"lon":[6.3419,5.4475,5.37,5.5396,4.3601],"marker":{"color":[20.544000000000004,23.07,20.580000000000002,20.284,24.548000000000002],"colorbar":{"title":{"text":"Temperature"}},"colorscale":[[0.0,"rgb(49,54,149)"],[0.1111111111111111,"rgb(69,117,180)"],[0.2222222222222222,"rgb(116,173,209)"],[0.3333333333333333,"rgb(171,217,233)"],[0.4444444444444444,"rgb(224,243,248)"],[0.5555555555555556,"rgb(254,224,144)"],[0.6666666666666666,"rgb(253,174,97)"],[0.7777777777777778,"rgb(244,109,67)"],[0.8888888888888888,"rgb(215,48,39)"],[1.0,"rgb(165,0,38)"]],"size":[2054.4000000000005,2307.0,2058.0,2028.3999999999999,2454.8],"sizemode":"area"},"name":"Ville","text":["Bormes les Mimosas","Aix en Provence","Marseille","Cassis","Nimes"],"type":"scattermapbox"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778, ...

# %%
#Graphique pour les hotels 
#TODO #https://plotly.com/python/v3/cars-exploration/

fig = go.Figure()

echelle_couleur=[[0.0, "rgb(49,54,149)"],
                [0.1111111111111111, "rgb(69,117,180)"],
                [0.2222222222222222, "rgb(116,173,209)"],
                [0.3333333333333333, "rgb(171,217,233)"],
                [0.4444444444444444, "rgb(224,243,248)"],
                [0.5555555555555556, "rgb(254,224,144)"],
                [0.6666666666666666, "rgb(253,174,97)"],
                [0.7777777777777778, "rgb(244,109,67)"],
                [0.8888888888888888, "rgb(215,48,39)"],
                [1.0,  "rgb(165,0,38)"]]


fig.add_trace(
    go.Scattermapbox(
        lon = df_rds_hotel_20['longitude'],
        lat = df_rds_hotel_20['latitude'],
        customdata=df_rds_hotel_20[['note','distance_center','prix','url','nom','description_aff']].values.tolist(),
        marker = dict(
            size = df_rds_hotel_20['note_aff'],
            sizemode = 'area',
            color=df_rds_hotel_20['prix'],
            colorbar=dict(
                    title="Tarif(€)"
                    )
        ),
        name = 'Nom',
        text = df_rds_hotel_20['nom'],
        #hoverinfo='none'
        hovertemplate="<b>Hotel :</b> %{text} <br> \
<b>Note :</b> %{customdata[0]} <br> \
<b>Prix :</b> %{customdata[2]} <br> \
<b>Distance du centre :</b> %{customdata[1]} <br> \
<b>Lien :</b> %{customdata[3]} <br> \
<b>escription :</b> %{customdata[5]} <br> "
   )
)

fig.update_layout(
        width=1000,
        height=1000,
        mapbox=dict(
            accesstoken=mapbox_access_token,
            bearing=0,
            center=go.layout.mapbox.Center(
                lat=47,
                lon=2
        ),
        zoom=5.1,
        pitch=0
))

fig.show()
# Out:
# <div>                            <div id="6746a231-7190-4106-949f-1a495452f9a2" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6746a231-7190-4106-949f-1a495452f9a2")) {                    Plotly.newPlot(                        "6746a231-7190-4106-949f-1a495452f9a2",                        [{"customdata":[[7.0,1.2,399.0,"https://www.booking.com/hotel/fr/le-royal-hotel-aigues-mortes.fr.html","Noemys Aigues-Mortes - ex Mona Lisa Royal H\u00f4tel","Certaines chambres offrent une vue sur la piscine ou le </br> jardin Tous les h\u00e9bergements sont pourvus d\u2019une t\u00e9l\u00e9vision \u00e0 \u00e9cran </br> plat et d\u2019une salle de bains privative. Certaines chambres disposent </br> \u00e9galement d'une terrasse priv\u00e9e.Un petit-d\u00e9jeuner buffet peut \u00eatre servi moyennant </br> un suppl\u00e9ment.Le Noemys Aigues-Mortes - ex Mona Lisa Royal H\u00f4tel </br> propose \u00e9galement des salles de r\u00e9union.N\u00eemes se trouve \u00e0 40 </br> km du Noemys Aigues-Mortes - ex Mona Lisa Royal H\u00f4tel, </br> tandis qu'Arles est \u00e0 45 km. L\u2019a\u00e9roport le plus proche, </br> celui de Montpellier-M\u00e9diterran\u00e9e, est \u00e0 26 km.  "],[8.3,1.2,459.0,"https://www.booking.com/hotel/fr/residence-odalys-fleur-de-sel.fr.html","R\u00e9sidence Odalys Fleur de Sel","R\u00e9partis en petits duplex, tous les appartements comportent une salle </br> de bains privative, un salon muni d'une t\u00e9l\u00e9vision \u00e0 \u00e9cran </br> plat et une kitchenette enti\u00e8rement \u00e9quip\u00e9e. Certains comprennent \u00e9galement une </br> terrasse ou un balcon.La R\u00e9sidence Odalys Fleur de Sel est </br> implant\u00e9e \u00e0 25 km de Montpellier. L'a\u00e9roport de Montpellier - </br> M\u00e9diterran\u00e9e se trouve, quant \u00e0 lui, \u00e0 18 km. Vous </br> pourrez profiter gratuitement d'un parking ext\u00e9rieur.  "],[null,0.6,460.0,"https://www.booking.com/hotel/fr/la-maison-d-amis-du-mas-lauseta-clim-et-park.fr.html","La Suite du Mas Lauseta - clim et park","L'appartement comprend une t\u00e9l\u00e9vision \u00e0 \u00e9cran plat. La cuisine est </br> \u00e9quip\u00e9e d'un r\u00e9frig\u00e9rateur, d'un micro-ondes, d'une machine \u00e0 caf\u00e9 et </br> d'une bouilloire.Vous s\u00e9journerez \u00e0 29 km de l'h\u00f4tel de ville </br> de Montpellier et \u00e0 32 km du Corum. L'a\u00e9roport de </br> Montpellier-M\u00e9diterran\u00e9e, le plus proche, est \u00e0 30 km.  "],[8.5,250.0,473.0,"https://www.booking.com/hotel/fr/la-maison-sur-la-place-aigues-mortes.fr.html","La maison sur la place","Cette maison de vacances climatis\u00e9e comprend 2 chambres, un salon, </br> une cuisine enti\u00e8rement \u00e9quip\u00e9e avec un r\u00e9frig\u00e9rateur et une machine </br> \u00e0 caf\u00e9 ainsi que 2 salles de bains pourvues d'une </br> douche et d'un s\u00e8che-cheveux. Les serviettes et le linge de </br> lit sont fournis.Vous s\u00e9journerez \u00e0 24 km de la salle </br> omnisports Montpellier Arena et du parc des expositions de Montpellier. </br> L'a\u00e9roport de Montpellier-M\u00e9diterran\u00e9e, le plus proche, est implant\u00e9 \u00e0 29 </br> km.  "],[8.5,0.8,491.0,"https://www.booking.com/hotel/fr/canal-aigues-mortes.fr.html","Hotel Canal Aigues Mortes","Toutes les chambres de cet h\u00f4tel 3 \u00e9toiles sont insonoris\u00e9es. </br> Elles comprennent une t\u00e9l\u00e9vision \u00e0 \u00e9cran plat avec des cha\u00eenes </br> nationales et internationales.Pendant les mois les plus chauds, vous d\u00e9gusterez </br> le petit-d\u00e9jeuner buffet sur la terrasse. En \u00e9t\u00e9, vous aurez </br> \u00e9galement la possibilit\u00e9 de prendre des collations ou des repas </br> l\u00e9gers au bord du canal.Un service de location de v\u00e9los </br> est assur ...

# %%
#Graphique pour les hotels dans nos 5 villes
#TODO #https://plotly.com/python/v3/cars-exploration/

fig = go.Figure()

echelle_couleur=[[0.0, "rgb(49,54,149)"],
                [0.1111111111111111, "rgb(69,117,180)"],
                [0.2222222222222222, "rgb(116,173,209)"],
                [0.3333333333333333, "rgb(171,217,233)"],
                [0.4444444444444444, "rgb(224,243,248)"],
                [0.5555555555555556, "rgb(254,224,144)"],
                [0.6666666666666666, "rgb(253,174,97)"],
                [0.7777777777777778, "rgb(244,109,67)"],
                [0.8888888888888888, "rgb(215,48,39)"],
                [1.0,  "rgb(165,0,38)"]]


fig.add_trace(
    go.Scattermapbox(
        lon = df_rds_hotel_20_in_5['longitude'],
        lat = df_rds_hotel_20_in_5['latitude'],
        customdata=df_rds_hotel_20_in_5[['note','distance_center','prix','url','nom','description_aff']].values.tolist(),
        marker = dict(
            size = df_rds_hotel_20_in_5['note_aff'],
            sizemode = 'area',
            color=df_rds_hotel_20_in_5['prix'],
            colorbar=dict(
                    title="Tarif(€)"
                    )
        ),
        name = 'Nom',
        text = df_rds_hotel_20_in_5['nom'],
        #hoverinfo='none'
        hovertemplate="<b>Hotel :</b> %{text} <br> \
<b>Note :</b> %{customdata[0]} <br> \
<b>Prix :</b> %{customdata[2]} <br> \
<b>Distance du centre :</b> %{customdata[1]} <br> \
<b>Lien :</b> %{customdata[3]} <br> \
<b>escription :</b> %{customdata[5]} <br> "
   )
)

fig.update_layout(
        width=1000,
        height=1000,
        mapbox=dict(
            accesstoken=mapbox_access_token,
            bearing=0,
            center=go.layout.mapbox.Center(
                lat=47,
                lon=2
        ),
        zoom=5.1,
        pitch=0
))

fig.show()
# Out:
# <div>                            <div id="7586354e-8bea-4f67-8953-01c4391dd75b" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7586354e-8bea-4f67-8953-01c4391dd75b")) {                    Plotly.newPlot(                        "7586354e-8bea-4f67-8953-01c4391dd75b",                        [{"customdata":[[5.0,1.8,200.0,"https://www.booking.com/hotel/fr/residence-nemea-aix-campus-1.fr.html","R\u00e9sidence N\u00e9m\u00e9a Aix Campus 1","L'h\u00e9bergement comprend une cuisine enti\u00e8rement \u00e9quip\u00e9e avec un r\u00e9frig\u00e9rateur et </br> une machine \u00e0 caf\u00e9, une t\u00e9l\u00e9vision et une salle de </br> bains privative avec douche.Vous s\u00e9journerez \u00e0 30 km du centre </br> commercial Les Terrasses du Port et de la station de </br> m\u00e9tro Vieux Port. L'a\u00e9roport de Marseille-Provence, le plus proche, est </br> implant\u00e9 \u00e0 25 km.  "],[8.0,9.0,284.0,"https://www.booking.com/hotel/fr/thecamp-amp-lodges.fr.html","thecamp h\u00f4tel Premium Lodge- Aix en Provence","Toutes les chambres sont \u00e9quip\u00e9es d'une t\u00e9l\u00e9vision par satellite \u00e0 </br> \u00e9cran plat, d'une bouilloire, d'une douche, d'articles de toilette gratuits </br> et d'un bureau. Certaines poss\u00e8dent \u00e9galement une cuisine avec un </br> r\u00e9frig\u00e9rateur, un four et un micro-ondes. Tous les logements comprennent </br> une armoire.L'h\u00f4tel sert un petit-d\u00e9jeuner buffet ou continental.Vous pourrez pratiquer </br> diverses activit\u00e9s \u00e0 Aix-en-Provence et dans ses environs, telles que </br> le v\u00e9lo et la randonn\u00e9e.Vous s\u00e9journerez \u00e0 25 km de </br> la station de m\u00e9tro Joliette et \u00e0 26 km de </br> celle du Vieux-Port. L'a\u00e9roport de Marseille-Provence, le plus proche, est </br> implant\u00e9 \u00e0 19 km.  "],[6.2,7.1,297.0,"https://www.booking.com/hotel/fr/tit-dej-aix-en-provence.fr.html","Aix Hotel","Les chambres de l\u2019Aix Hotel sont pourvues d\u2019une salle de </br> bains privative. Les chambres sont toutes climatis\u00e9es.Chaque matin, l\u2019Aix Hotel </br> sert un petit-d\u00e9jeuner buffet de 5h30 \u00e0 9h30. Vous pourrez </br> \u00e9galement prendre une collation et une boisson moyennant des frais </br> suppl\u00e9mentaires.L'\u00e9tablissement poss\u00e8de par ailleurs une r\u00e9ception ouverte 24h/24 et une </br> terrasse. Le parking priv\u00e9 est gratuit.\nL\u2019Aix Hotel est install\u00e9 \u00e0 </br> 5 km du centre-ville d\u2019Aix-en-Provence et \u00e0 25 minutes de </br> route de Marseille. Martigues est accessible en 30 minutes en </br> voiture.L'Aix Hotel est d\u00e9sormais \u00e9quip\u00e9 d'une station de recharge \u00e9lectrique. </br>  "],[6.9,2.4,299.0,"https://www.booking.com/hotel/fr/arc-aix-hotel.fr.html","Adonis Arc Hotel Aix","Toutes les chambres sont pourvues d'une salle de bains privative </br> avec une baignoire, d'un bureau, d'une t\u00e9l\u00e9vision \u00e0 \u00e9cran plat </br> et d'un t\u00e9l\u00e9phone.Un petit-d\u00e9jeuner buffet est propos\u00e9 tous les jours. </br> Vous pourrez commander des boissons au bar et les d\u00e9guster </br> au bord de la piscine. Des transats sont \u00e0 votre </br> disposition sur la terrasse bien expos\u00e9e.La r\u00e9ception est ouverte 24h/24. </br> L'Adonis Arc Hotel Aix se trouve \u00e0 seulement 3 minutes </br> en voiture de l'autoroute A8, sortie 31, menant \u00e0 Marseille </br> ou \u00e0 Nice. L'\u00e9tablissement poss\u00e8de un parking priv\u00e9 gratuit.  </br> "],[7.2,1.6,307.0,"https://www.booking.com/hotel/fr/appart-valley-aix-en-provence.fr.html","City R\u00e9sidence Aix-en-Provence","Chaque studio ou appartement climatis\u00e9 et insonoris\u00e9 dispose d'une kitchenette </br> avec des plaques de cuisson, un mic ...

# %% [markdown]
# ## Etape 8 : Ouverture...

# %%
#Pour les graphiques : Proposer la gestion des filtres en live sur les graphes
#Suite à l'apprentissage de streamlit : Utiliser Streamlit !! 
#cf #https://plotly.com/python/v3/cars-exploration/

#Pour les appels API : 
#Passer les scripts en Asynchrone de sorte à gagner du temps 

#Pour le scrapping : 
#Comme nous avons une liste finie de ville à scrapper, l'idéal serait de lancer 1 ville / process 
#Mettre en place des proxy rotatif pour éviter le ban
#Récupérer des photos et afficher ca sur une map html comme un site

#Pour la partie ETL : 
#Ameliorer le système de mise à jour avec une date d'insertion des données et définir une période de validité de ces données

#Pour la sélection des hotels et de la méteo 
#Demander à l'utilisateur de choisir ses préférences entre le prix etc... et filtrer tous les hotels de toutes les villes sur ces critères
    #Sélection des 20 hotels à afficher
    #On prend les hotels avec note générale de 8
    #Avec une distance du centre de moins de 1km
    #avec un prix compris entre moyenne - 1 ecart type et moyenne + 1 ecart type
    #mask = (df_rds_hotel['note'] > 8) & (df_rds_hotel['distance_center'] < 1) & (df_rds_hotel['prix'] < (df_rds_hotel['prix'].mean() + df_rds_hotel['prix'].mean())) & (df_rds_hotel['prix'] > (df_rds_hotel['prix'].mean() - df_rds_hotel['prix'].mean()))
#Matcher avec les meilleurs météo 
#Récupérer une liste de 3 Hotels qui sont parfaits
